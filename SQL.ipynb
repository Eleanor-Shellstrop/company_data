# %%
import os
import sqlite3
import pandas as pd

# %%
os.listdir(os.getcwd())
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'company',
#  'csv',
#  'database',
#  'Database Automation.ipynb',
#  'datasets',
#  'original_csvs',
#  'README.md',
#  'SQL.ipynb']

# %%
os.chdir('database')

# %%
conn = sqlite3.connect('company')
c = conn.cursor()

c.execute('''
SELECT
    company_orders.company_name,
    contact_first_name,
    contact_last_name,
    order_amount
FROM
    company_orders
LEFT JOIN company_client_list ON company_client_list.company_name = company_orders.company_name
WHERE company_client_list.contact_last_name IS NULL;
''')

missing_clients = []

for row in c.fetchall():
    clients.append(row)
    print(row)
    
conn.commit()
conn.close()
# Out:
# ('Buzzbean', None, None, '$1607033.03')
# ('Twitternation', None, None, '$2938905.06')
# ('Yakijo', None, None, '$900012.38')
# ('Divavu', None, None, '$2589224.75')
# ('Skajo', None, None, '$545984.63')
# ('Kwideo', None, None, '$2905127.21')
# ('Realbuzz', None, None, '$896149.13')
# ('Devcast', None, None, '$684204.84')
# ('Jamia', None, None, '$1203020.19')
# ('Abatz', None, None, '$2399041.79')
# ('Twimm', None, None, '$1613750.41')
# ('BlogXS', None, None, '$1241424.67')
# ('Yoveo', None, None, '$535564.98')
# ('Midel', None, None, '$1666373.95')
# ('Janyx', None, None, '$792387.13')
# ('Oyoba', None, None, '$2987405.59')
# ('Kwideo', None, None, '$647709.82')
# ('Topicware', None, None, '$235476.34')
# ('Wikizz', None, None, '$1692282.96')
# ('Thoughtworks', None, None, '$2158940.17')
# ('Jaxworks', None, None, '$1047991.30')
# ('Snaptags', None, None, '$2235972.98')
# ('Yombu', None, None, '$923100.48')
# ('Skinder', None, None, '$949982.98')
# ('Shufflebeat', None, None, '$1810987.37')
# ('Jamia', None, None, '$1072587.30')
# ('Skinte', None, None, '$2172618.82')
# ('Brainverse', None, None, '$2459146.86')
# ('Eayo', None, None, '$717155.94')
# ('Edgepulse', None, None, '$1508322.32')
# ('Topiclounge', None, None, '$2271324.05')
# ('Fanoodle', None, None, '$832731.86')
# ('Demimbu', None, None, '$2082571.99')
# ('Kimia', None, None, '$91321.77')
# ('Zooxo', None, None, '$2470548.58')
# ('Flipopia', None, None, '$887852.30')
# ('Wordpedia', None, None, '$2404898.26')
# ('Skiptube', None, None, '$1164898.86')
# ('Zoonoodle', None, None, '$2603153.30')
# ('Devcast', None, None, '$2826322.52')
# ('Fliptune', None, None, '$386066.99')
# ('Yabox', None, None, '$895857.09')
# ('Midel', None, None, '$828832.16')
# ('Tazzy', None, None, '$2437870.58')
# ('Skiptube', None, None, '$263162.28')
# ('Yodo', None, None, '$2575419.21')
# ('Jetwire', None, None, '$1026227.21')
# ('Cogidoo', None, None, '$549907.95')
# ('Yakitri', None, None, '$1432700.81')
# ('Linklinks', None, None, '$789139.95')
# ('Rhynyx', None, None, '$899148.54')
# ('Edgeblab', None, None, '$2572682.13')
# ('Viva', None, None, '$1217924.55')
# ('Yakijo', None, None, '$407226.23')
# ('Jetpulse', None, None, '$2246047.50')
# ('Twinte', None, None, '$2835113.03')
# ('Devpoint', None, None, '$327327.50')
# ('Fivechat', None, None, '$1291823.28')
# ('Dabtype', None, None, '$1230775.28')
# ('Feedfire', None, None, '$1832504.10')
# ('Rooxo', None, None, '$1907024.88')
# ('Photobean', None, None, '$2233224.15')
# ('Thoughtworks', None, None, '$500736.08')
# ('Youfeed', None, None, '$2249603.83')
# ('Skipfire', None, None, '$2061783.70')
# ('Jabberbean', None, None, '$2719896.62')
# ('Zooxo', None, None, '$983468.06')
# ('Shufflester', None, None, '$1676175.45')
# ('Divavu', None, None, '$2404594.27')
# ('DabZ', None, None, '$2423958.37')
# ('Trupe', None, None, '$2414203.77')
# ('Fanoodle', None, None, '$538128.43')
# ('Meezzy', None, None, '$1903449.82')
# ('Vimbo', None, None, '$1696137.60')
# ('Tazzy', None, None, '$634123.92')
# ('Chatterpoint', None, None, '$2937304.85')
# ('Trilia', None, None, '$2001330.20')
# ('Twinder', None, None, '$1066813.59')
# ('Rhynyx', None, None, '$2165815.61')
# ('Jabbercube', None, None, '$2889074.89')
# ('Zooxo', None, None, '$2308733.29')
# ('Jaloo', None, None, '$690100.45')
# ('Twitterbeat', None, None, '$1723930.47')
# ('Lajo', None, None, '$2962686.42')
# ('Fliptune', None, None, '$1535862.65')
# ('Oyoba', None, None, '$164386.31')
# ('Realbridge', None, None, '$894259.38')
# ('Mydo', None, None, '$2430157.90')
# ('Tanoodle', None, None, '$296719.18')
# ('Agimba', None, None, '$42850.68')
# ('Demimbu', None, None, '$2365862.91')
# ('Mudo', None, None, '$2985375.13')
# ('Dabjam', None, None, '$165370.74')
# ('Mudo', None, None, '$1789257.40')
# ('Innojam', None, None, '$2218809.51')
# ('Linklinks', None, None, '$16526.10')
# ('Skajo', None, None, '$524095.53')
# ('Jaxnation', None, None, '$2883236.41')
# ('Edgetag', None, None, '$1084460.27')
# ('Flashspan', None, None, '$2818490.57')
# ('BlogXS', None, None, '$1981775.36')
# ('Fanoodle', None, None, '$1731476.45')
# ('Twitterworks', None, None, '$1512596.52')
# ('Divavu', None, None, '$917729.37')
# ('Tagcat', None, None, '$2998636.77')
# ('Feednation', None, None, '$1682279.57')
# ('Plajo', None, None, '$2245615.09')
# ('Tagcat', None, None, '$1137484.13')
# ('Janyx', None, None, '$723457.91')
# ('Nlounge', None, None, '$1825920.13')
# ('Aimbu', None, None, '$390359.47')
# ('Devify', None, None, '$2618134.82')
# ('Jetwire', None, None, '$159482.00')
# ('Geba', None, None, '$2053888.24')
# ('Riffwire', None, None, '$2467741.77')
# ('Youspan', None, None, '$538300.18')
# ('Browseblab', None, None, '$1686958.47')
# ('Skinix', None, None, '$784627.68')
# ('Eidel', None, None, '$2519173.00')
# ('Brightdog', None, None, '$1341521.99')
# ('Skiba', None, None, '$698043.96')
# ('Chatterbridge', None, None, '$1796972.37')
# ('Meedoo', None, None, '$1571158.17')
# ('Browseblab', None, None, '$2133462.81')
# ('Quatz', None, None, '$1387554.72')
# ('Browsezoom', None, None, '$2325365.17')
# ('Jaxnation', None, None, '$706551.35')
# ('Voolith', None, None, '$2605017.56')
# ('Chatterbridge', None, None, '$1059580.08')
# ('Flashspan', None, None, '$277801.22')
# ('Tagcat', None, None, '$1947562.18')
# ('Dabjam', None, None, '$893637.33')
# ('Vinte', None, None, '$639489.40')
# ('Jamia', None, None, '$2420843.95')
# ('Skyba', None, None, '$1856171.11')
# ('Flipbug', None, None, '$1320707.58')
# ('Brightbean', None, None, '$857856.67')
# ('Realfire', None, None, '$2133179.38')
# ('Blogspan', None, None, '$2977468.85')
# ('Yozio', None, None, '$613111.47')
# ('Babblestorm', None, None, '$1085964.09')
# ('Talane', None, None, '$1478477.56')
# ('Skajo', None, None, '$2293035.24')
# ('Fiveclub', None, None, '$933148.44')
# ('Viva', None, None, '$2940722.01')
# ('Wordpedia', None, None, '$319951.70')
# ('Izio', None, None, '$2861840.69')
# ('Vipe', None, None, '$1033411.15')
# ('Divavu', None, None, '$1919073.10')
# ('Devify', None, None, '$113545.04')
# ('Gigashots', None, None, '$108642.76')
# ('Edgeblab', None, None, '$2141404.03')
# ('Dabjam', None, None, '$782703.31')
# ('Tagopia', None, None, '$93467.05')
# ('Skajo', None, None, '$304464.86')
# ('Camido', None, None, '$2469835.56')
# ('Talane', None, None, '$1512345.21')
# ('Divanoodle', None, None, '$1893324.62')
# ('Shuffletag', None, None, '$1439871.37')
# ('Voomm', None, None, '$249824.89')
# ('Mydeo', None, None, '$1109598.24')
# ('Kayveo', None, None, '$2707287.59')
# ('Pixope', None, None, '$383205.91')
# ('Trudeo', None, None, '$2156900.15')
# ('Trilith', None, None, '$210857.31')
# ('Quire', None, None, '$604166.42')
# ('Leexo', None, None, '$2045910.29')
# ('Fliptune', None, None, '$2020987.12')
# ('Yozio', None, None, '$2641030.68')
# ('Thoughtbeat', None, None, '$2404151.46')
# ('Vimbo', None, None, '$1468540.20')
# ('Skinix', None, None, '$2975650.25')
# ('Quatz', None, None, '$2713091.93')
# ('Tazzy', None, None, '$2149006.07')
# ('Feedspan', None, None, '$2125771.02')
# ('Centimia', None, None, '$2180065.83')
# ('Dabshots', None, None, '$817865.55')
# ('Mymm', None, None, '$2156582.12')
# ('Devpulse', None, None, '$477170.01')
# ('Devpulse', None, None, '$2705209.67')
# ('Voolith', None, None, '$407021.58')
# ('Trilia', None, None, '$2203600.34')
# ('Skinder', None, None, '$134190.77')
# ('Innotype', None, None, '$2064400.05')
# ('Voomm', None, None, '$372644.26')
# ('Lajo', None, None, '$2457565.10')
# ('Trudeo', None, None, '$2769145.02')
# ('Youspan', None, None, '$148543.54')
# ('Edgepulse', None, None, '$537315.03')
# ('Bluejam', None, None, '$1351418.50')
# ('Skinder', None, None, '$1669731.44')
# ('Divavu', None, None, '$2314793.76')
# ('Wikizz', None, None, '$2449739.55')
# ('Quimm', None, None, '$271053.08')
# ('Yakitri', None, None, '$1540217.06')
# ('Trudoo', None, None, '$842630.77')
# ('Camido', None, None, '$2960754.65')
# ('Jaxspan', None, None, '$2122016.08')
# ('Zoomdog', None, None, '$717549.13')
# ('Centizu', None, None, '$1649141.48')
# ('Cogibox', None, None, '$1130703.11')
# ('Eabox', None, None, '$2629074.00')
# ('Youspan', None, None, '$450312.72')
# ('Linktype', None, None, '$482649.75')
# ('Eimbee', None, None, '$452444.58')
# ('Yotz', None, None, '$1531507.48')
# ('Fanoodle', None, None, '$2076494.16')
# ('Gigashots', None, None, '$1964334.01')
# ('Blogpad', None, None, '$1873422.28')
# ('Wikivu', None, None, '$2352805.36')
# ('Jabbercube', None, None, '$1847268.72')
# ('Quimba', None, None, '$638709.79')
# ('Jaxworks', None, None, '$359920.93')
# ('Trupe', None, None, '$2945474.49')
# ('Abatz', None, None, '$2178756.56')
# ('Topicblab', None, None, '$1762869.75')
# ('Dabjam', None, None, '$964349.02')
# ('Tagchat', None, None, '$146003.08')
# ('Dabjam', None, None, '$849899.57')
# ('Twimm', None, None, '$1703753.09')
# ('Zoonder', None, None, '$970244.29')
# ('Shufflebeat', None, None, '$2625009.64')
# ('Flipopia', None, None, '$2164030.89')
# ('Skibox', None, None, '$1478399.84')
# ('Skippad', None, None, '$2116481.02')
# ('Vitz', None, None, '$380781.53')
# ('Dynazzy', None, None, '$792906.07')
# ('Yombu', None, None, '$2185983.21')
# ('Tagopia', None, None, '$1708052.16')
# ('Roomm', None, None, '$2139521.00')
# ('Mymm', None, None, '$326883.81')
# ('Skimia', None, None, '$2757205.33')
# ('Voonte', None, None, '$1770486.59')
# ('Eayo', None, None, '$1196191.20')
# ('Ooba', None, None, '$2729249.34')
# ('Yakijo', None, None, '$57279.77')
# ('Tagopia', None, None, '$1937209.58')
# ('Wordtune', None, None, '$2052952.03')
# ('Fivebridge', None, None, '$437727.54')
# ('Digitube', None, None, '$1902034.22')
# ('Flipbug', None, None, '$2046359.11')
# ('Dynava', None, None, '$355006.46')
# ('Ailane', None, None, '$2014798.42')
# ('Trudeo', None, None, '$2952879.67')
# ('Kwilith', None, None, '$702889.30')
# ('Viva', None, None, '$2274528.59')
# ('Pixope', None, None, '$948831.44')
# ('Devpoint', None, None, '$186180.29')
# ('Fivechat', None, None, '$1031480.12')
# ('Youopia', None, None, '$2821513.82')
# ('Photolist', None, None, '$1427129.93')
# ('Devshare', None, None, '$1500575.41')
# ('Meevee', None, None, '$1815555.83')
# ('Viva', None, None, '$2746212.25')
# ('Lazzy', None, None, '$2305977.49')
# ('Rooxo', None, None, '$988711.89')
# ('Skippad', None, None, '$448965.30')
# ('Jabbersphere', None, None, '$2192166.82')
# ('Twinder', None, None, '$2277898.22')
# ('Quaxo', None, None, '$1154545.58')
# ('Kwilith', None, None, '$2740451.88')
# ('Centizu', None, None, '$259558.37')
# ('Zoombox', None, None, '$588502.24')
# ('Zava', None, None, '$160391.11')
# ('Oyoba', None, None, '$1160137.43')
# ('Oyoyo', None, None, '$2462778.23')
# ('Photolist', None, None, '$1540781.37')
# ('Babbleblab', None, None, '$2323611.57')
# ('Lazzy', None, None, '$1134241.12')
# ('Twitterworks', None, None, '$1758626.84')
# ('Flashset', None, None, '$1278243.35')
# ('Divanoodle', None, None, '$1361404.79')
# ('Edgetag', None, None, '$455437.55')
# ('Edgeclub', None, None, '$2159590.18')
# ('Blogspan', None, None, '$1521571.41')
# ('Teklist', None, None, '$2429787.83')
# ('Twitternation', None, None, '$2705937.39')
# ('Buzzdog', None, None, '$120901.47')
# ('Topicblab', None, None, '$396529.60')
# ('Dabfeed', None, None, '$2817864.72')
# ('Skidoo', None, None, '$408312.62')
# ('Linktype', None, None, '$2816039.17')
# ('Gigazoom', None, None, '$646704.09')
# ('Thoughtbeat', None, None, '$277794.45')
# ('Blogtags', None, None, '$726923.24')
# ('Camido', None, None, '$1411841.36')
# ('Quimba', None, None, '$937142.76')
# ('Livepath', None, None, '$1565693.65')
# ('Cogidoo', None, None, '$2249775.78')
# ('Twitternation', None, None, '$2651867.59')
# ('Buzzbean', None, None, '$1564699.61')
# ('Jabbercube', None, None, '$1637559.68')
# ('Browsezoom', None, None, '$741492.19')
# ('Topiclounge', None, None, '$793637.41')
# ('Yodo', None, None, '$813630.29')
# ('Wordtune', None, None, '$2733635.37')
# ('Realbuzz', None, None, '$1660318.25')
# ('Yakidoo', None, None, '$2052743.23')
# ('Twimm', None, None, '$214169.66')
# ('Tagtune', None, None, '$2327565.10')
# ('Yacero', None, None, '$981807.73')
# ('Buzzdog', None, None, '$1503704.01')
# ('Bluejam', None, None, '$427580.16')
# ('Oyonder', None, None, '$638142.65')
# ('Zoovu', None, None, '$2464451.60')
# ('Plambee', None, None, '$2303973.16')
# ('Gabcube', None, None, '$2129237.93')
# ('Eimbee', None, None, '$2841314.60')
# ('Oyondu', None, None, '$901261.94')
# ('Jetwire', None, None, '$1177187.73')
# ('Centimia', None, None, '$2405969.84')
# ('Fivechat', None, None, '$1715984.74')
# ('Tazzy', None, None, '$2929059.86')
# ('Gabtune', None, None, '$718467.73')
# ('Thoughtmix', None, None, '$2702008.63')
# ('Jaxnation', None, None, '$2034257.34')
# ('Viva', None, None, '$2060186.64')
# ('Kwimbee', None, None, '$1673816.05')
# ('Rhynoodle', None, None, '$842192.86')
# ('Skinte', None, None, '$1850373.61')
# ('Wordpedia', None, None, '$2829430.70')
# ('Linktype', None, None, '$902623.88')
# ('Thoughtblab', None, None, '$2654763.28')
# ('Aimbo', None, None, '$875279.39')
# ('Eidel', None, None, '$640466.43')
# ('Jabberstorm', None, None, '$1057572.01')
# ('Meeveo', None, None, '$1184487.07')
# ('Youfeed', None, None, '$2382957.41')
# ('Twimbo', None, None, '$1703861.91')
# ('Skinte', None, None, '$1651132.01')
# ('Shufflebeat', None, None, '$2801178.28')
# ('Devpoint', None, None, '$1301195.25')
# ('Realfire', None, None, '$189621.95')
# ('Edgepulse', None, None, '$2210680.01')
# ('Mybuzz', None, None, '$236587.76')
# ('Gigazoom', None, None, '$965819.74')
# ('Quaxo', None, None, '$448662.61')
# ('Wikizz', None, None, '$2014174.82')
# ('Brainsphere', None, None, '$2812759.31')
# ('Tagchat', None, None, '$729789.75')
# ('Quamba', None, None, '$1527813.96')
# ('Zoonder', None, None, '$89615.70')
# ('Tanoodle', None, None, '$1351299.41')
# ('Blognation', None, None, '$2108422.02')
# ('Nlounge', None, None, '$2177702.60')
# ('Eayo', None, None, '$1579671.67')
# ('Tagopia', None, None, '$1732143.46')
# ('Wordware', None, None, '$2288638.69')
# ('Vinte', None, None, '$1026534.47')
# ('Lazzy', None, None, '$1811774.48')
# ('Kimia', None, None, '$2565259.73')
# ('Centimia', None, None, '$2697297.21')
# ('Skipfire', None, None, '$2745383.96')
# ('Feedfire', None, None, '$151470.02')
# ('Kwimbee', None, None, '$432143.24')
# ('Voonder', None, None, '$1889430.78')
# ('Camimbo', None, None, '$1021276.28')
# ('Dabshots', None, None, '$1740076.12')
# ('Jabberstorm', None, None, '$771732.07')
# ('Jamia', None, None, '$1212432.96')
# ('Trupe', None, None, '$1673708.14')
# ('Bubbletube', None, None, '$897070.94')
# ('Quatz', None, None, '$1798354.49')
# ('Yacero', None, None, '$57415.15')
# ('Fadeo', None, None, '$996286.48')
# ('Twitterlist', None, None, '$2023835.17')
# ('JumpXS', None, None, '$2807261.77')
# ('Camido', None, None, '$1058919.99')
# ('Plambee', None, None, '$1171102.16')
# ('Thoughtmix', None, None, '$1929966.28')
# ('Bluejam', None, None, '$274828.95')
# ('Oyonder', None, None, '$1945435.09')
# ('Oyoloo', None, None, '$1247529.85')
# ('Centimia', None, None, '$742065.95')
# ('Babblestorm', None, None, '$419469.36')
# ('Ozu', None, None, '$1205496.26')
# ('Oloo', None, None, '$82975.28')
# ('Twitterwire', None, None, '$1432742.31')
# ('Oyoba', None, None, '$1598122.75')
# ('Jaxworks', None, None, '$798169.37')
# ('Realbuzz', None, None, '$853479.88')
# ('Meeveo', None, None, '$752515.95')
# ('Miboo', None, None, '$87317.36')
# ('Skiba', None, None, '$2878526.67')
# ('Devpulse', None, None, '$2659083.12')
# ('Shufflester', None, None, '$2139029.96')
# ('Fliptune', None, None, '$250194.39')
# ('Bluezoom', None, None, '$1750655.17')
# ('Thoughtblab', None, None, '$2793948.88')
# ('Tagchat', None, None, '$920726.62')
# ('Ntag', None, None, '$1886696.33')
# ('Oyoloo', None, None, '$2448537.01')
# ('Quaxo', None, None, '$551084.13')
# ('Skibox', None, None, '$231053.69')
# ('Twitternation', None, None, '$2909120.31')
# ('Thoughtbeat', None, None, '$665983.02')
# ('Jamia', None, None, '$2504667.05')
# ('Buzzbean', None, None, '$2040261.32')
# ('Browseblab', None, None, '$2494183.43')
# ('Yabox', None, None, '$303827.66')
# ('Talane', None, None, '$2234542.67')
# ('Eimbee', None, None, '$2303771.10')
# ('Leexo', None, None, '$1512390.36')
# ('Ntags', None, None, '$964553.59')
# ('Bluejam', None, None, '$2044053.40')
# ('Eimbee', None, None, '$2010523.03')
# ('Twitterbeat', None, None, '$863141.01')
# ('Gevee', None, None, '$740672.17')
# ('Centimia', None, None, '$183306.50')
# ('Jazzy', None, None, '$1685744.97')
# ('Leexo', None, None, '$267665.45')
# ('Bubbletube', None, None, '$1243815.88')
# ('Buzzbean', None, None, '$1262693.41')
# ('Mydo', None, None, '$2541987.62')
# ('Miboo', None, None, '$947101.12')
# ('Quire', None, None, '$548744.52')
# ('Browseblab', None, None, '$940561.03')
# ('Skinder', None, None, '$1953451.99')
# ('Jabberbean', None, None, '$2199277.38')
# ('Janyx', None, None, '$770864.36')
# ('Blognation', None, None, '$2448151.77')
# ('Trunyx', None, None, '$933917.99')
# ('Ntag', None, None, '$2341483.82')
# ('Yodoo', None, None, '$2252594.68')
# ('Devshare', None, None, '$474727.83')
# ('Blogpad', None, None, '$2321659.07')
# ('Bubblebox', None, None, '$2677618.25')
# ('Devshare', None, None, '$650533.09')
# ('Skyble', None, None, '$2019816.43')
# ('Zoovu', None, None, '$2887143.08')
# ('Devshare', None, None, '$2736647.48')
# ('Quimm', None, None, '$2639154.06')
# ('Bluezoom', None, None, '$361264.39')
# ('Yodel', None, None, '$506177.64')
# ('Skyndu', None, None, '$286099.72')
# ('Fivebridge', None, None, '$2413380.05')
# ('Digitube', None, None, '$1427701.08')
# ('Meezzy', None, None, '$960190.06')
# ('Gigabox', None, None, '$2851457.68')
# ('Devpoint', None, None, '$2820339.44')
# ('Trudoo', None, None, '$657952.90')
# ('Ooba', None, None, '$1054351.75')
# ('Tavu', None, None, '$2192291.28')
# ('Shuffledrive', None, None, '$223469.08')
# ('Oyoloo', None, None, '$2198852.08')
# ('Flashdog', None, None, '$813610.66')
# ('Aimbo', None, None, '$1850738.33')
# ('Yodo', None, None, '$1022864.14')
# ('Babbleblab', None, None, '$1229753.99')
# ('Gigashots', None, None, '$948609.27')
# ('Rhynyx', None, None, '$1589156.89')
# ('Quamba', None, None, '$733923.52')
# ('Bubblebox', None, None, '$2844777.20')
# ('Vitz', None, None, '$770124.94')
# ('Babblestorm', None, None, '$1269327.63')
# ('Aimbu', None, None, '$2377943.64')
# ('Brightbean', None, None, '$2684589.10')
# ('Mydo', None, None, '$2317660.54')
# ('Wordpedia', None, None, '$77157.95')
# ('Vipe', None, None, '$155642.18')
# ('Realpoint', None, None, '$1118154.11')
# ('Fliptune', None, None, '$1375067.82')
# ('Linktype', None, None, '$834286.28')
# ('Tagcat', None, None, '$1687014.05')
# ('Thoughtblab', None, None, '$1953979.98')
# ('Topicware', None, None, '$1287701.18')
# ('Babbleset', None, None, '$2448716.50')
# ('Voonte', None, None, '$1771019.83')
# ('Quire', None, None, '$556505.76')
# ('Latz', None, None, '$121470.07')
# ('Blognation', None, None, '$2263606.15')
# ('Muxo', None, None, '$2955210.62')
# ('Izio', None, None, '$1160267.50')
# ('Edgepulse', None, None, '$2727856.77')
# ('Vidoo', None, None, '$2684772.34')
# ('Brightdog', None, None, '$842422.77')
# ('Zoomzone', None, None, '$2663394.50')
# ('Gigabox', None, None, '$714724.16')
# ('Topicware', None, None, '$1487503.27')
# ('Wordify', None, None, '$1313278.85')
# ('Demimbu', None, None, '$1982576.09')
# ('Janyx', None, None, '$2410054.52')
# ('Dynava', None, None, '$2108665.78')
# ('Realpoint', None, None, '$2064206.09')
# ('Flipopia', None, None, '$2915937.33')
# ('Yakitri', None, None, '$810285.42')
# ('Gabtune', None, None, '$1728673.24')
# ('Tagpad', None, None, '$943594.56')
# ('Jamia', None, None, '$1036374.06')
# ('Topdrive', None, None, '$20399.29')
# ('Flipopia', None, None, '$1079166.16')
# ('Feednation', None, None, '$2353779.24')
# ('Eimbee', None, None, '$299019.46')
# ('Devcast', None, None, '$2810990.49')
# ('Trudoo', None, None, '$682669.27')
# ('Meezzy', None, None, '$419358.27')
# ('Kimia', None, None, '$1951085.85')
# ('Ntags', None, None, '$1304768.94')
# ('Trupe', None, None, '$570803.02')
# ('Aimbu', None, None, '$2958104.14')
# ('Pixope', None, None, '$1409405.23')
# ('Aibox', None, None, '$1909359.99')
# ('Trunyx', None, None, '$35982.25')
# ('Ailane', None, None, '$1619436.93')
# ('Latz', None, None, '$770368.33')
# ('Gigabox', None, None, '$2673311.30')
# ('Oyoba', None, None, '$2123971.93')
# ('Talane', None, None, '$1817128.49')
# ('Fanoodle', None, None, '$2533767.18')
# ('Voonder', None, None, '$801657.34')
# ('Yodoo', None, None, '$53680.02')
# ('Buzzdog', None, None, '$742837.19')
# ('Photobean', None, None, '$432435.16')
# ('Camido', None, None, '$206229.10')
# ('Quire', None, None, '$1690612.98')
# ('Jabbercube', None, None, '$2958167.86')
# ('Voonder', None, None, '$983243.35')
# ('Fliptune', None, None, '$2627144.74')
# ('Jaxnation', None, None, '$664489.19')
# ('Muxo', None, None, '$1818208.33')
# ('Jaxspan', None, None, '$1851068.17')
# ('Jaxbean', None, None, '$567512.58')
# ('Bubbletube', None, None, '$1257013.44')
# ('Twitternation', None, None, '$159855.11')
# ('Brainverse', None, None, '$1639705.89')
# ('Feednation', None, None, '$2855031.10')
# ('Realmix', None, None, '$2839164.46')
# ('Meedoo', None, None, '$2746085.98')
# ('Livefish', None, None, '$2656259.79')
# ('Skyndu', None, None, '$66912.53')
# ('Skinder', None, None, '$1161252.34')
# ('Voolith', None, None, '$1770950.63')
# ('Flipopia', None, None, '$2237530.23')
# ('Riffwire', None, None, '$1628739.07')
# ('Oyoba', None, None, '$2099481.91')
# ('Abatz', None, None, '$2122919.75')
# ('Meevee', None, None, '$2346826.95')
# ('Topicware', None, None, '$882296.84')
# ('Lajo', None, None, '$1466890.47')
# ('Digitube', None, None, '$1089746.31')
# ('Blogtag', None, None, '$1709125.51')
# ('Thoughtbeat', None, None, '$890699.75')
# ('Twimbo', None, None, '$429602.80')
# ('Ooba', None, None, '$1593355.31')
# ('Jabbersphere', None, None, '$599294.30')
# ('Yakitri', None, None, '$525935.38')
# ('Quatz', None, None, '$2543147.33')
# ('Browseblab', None, None, '$1454094.04')
# ('Browseblab', None, None, '$584542.43')
# ('Yakidoo', None, None, '$2896502.42')
# ('Trunyx', None, None, '$1946921.28')
# ('Skyndu', None, None, '$1854209.46')
# ('Meeveo', None, None, '$185800.73')
# ('Skimia', None, None, '$177397.42')
# ('Thoughtbeat', None, None, '$740276.60')
# ('Quimba', None, None, '$1055992.93')
# ('Browseblab', None, None, '$2140966.20')
# ('Rhycero', None, None, '$1189194.96')
# ('Devcast', None, None, '$1149836.64')
# ('Ailane', None, None, '$1134138.11')
# ('Shufflebeat', None, None, '$959952.34')
# ('Topicblab', None, None, '$1732238.04')
# ('Abata', None, None, '$2357547.30')
# ('Meevee', None, None, '$1804320.26')
# ('Photojam', None, None, '$1515681.52')
# ('Thoughtblab', None, None, '$2083630.17')
# ('Viva', None, None, '$783500.21')
# ('Rhynyx', None, None, '$2001423.96')
# ('Devpoint', None, None, '$340235.78')
# ('Kwilith', None, None, '$849362.42')
# ('Gevee', None, None, '$134806.49')
# ('Skinder', None, None, '$798523.21')
# ('Browseblab', None, None, '$564877.92')
# ('Photolist', None, None, '$1750007.52')
# ('Roomm', None, None, '$2061980.15')
# ('Kimia', None, None, '$819449.90')
# ('Oodoo', None, None, '$31797.13')
# ('Quire', None, None, '$1186467.74')
# ('Cogidoo', None, None, '$1643505.13')
# ('Cogidoo', None, None, '$1853933.81')
# ('Buzzshare', None, None, '$1192479.92')
# ('Wikizz', None, None, '$1354933.97')
# ('Yambee', None, None, '$1153767.48')
# ('Wikido', None, None, '$2580642.30')
# ('Voonix', None, None, '$1057547.05')
# ('Camido', None, None, '$1626756.46')
# ('Eamia', None, None, '$1442432.48')
# ('Kayveo', None, None, '$534468.82')
# ('Youspan', None, None, '$2773046.79')
# ('Photospace', None, None, '$799911.59')
# ('Devpulse', None, None, '$680049.76')
# ('Yakijo', None, None, '$2898197.25')
# ('Divavu', None, None, '$764965.52')
# ('Tagopia', None, None, '$2363557.88')
# ('Abata', None, None, '$2981327.46')
# ('Rhynyx', None, None, '$1146579.06')
# ('Eazzy', None, None, '$214322.38')
# ('Kimia', None, None, '$1775616.59')
# ('Camido', None, None, '$1082331.46')
# ('Zoonoodle', None, None, '$1638284.16')
# ('Voolia', None, None, '$443053.95')
# ('Eabox', None, None, '$2256797.27')
# ('Quatz', None, None, '$1803714.40')
# ('Quimm', None, None, '$278292.60')
# ('Browseblab', None, None, '$1888993.20')
# ('Devshare', None, None, '$2106917.95')
# ('Photospace', None, None, '$2985566.19')
# ('Kwilith', None, None, '$639930.12')
# ('Gigazoom', None, None, '$2476894.43')
# ('Twitterlist', None, None, '$424457.77')
# ('Babbleblab', None, None, '$1177780.31')
# ('Blognation', None, None, '$833278.54')
# ('Realbuzz', None, None, '$2684459.51')
# ('Yabox', None, None, '$511177.02')
# ('Realbridge', None, None, '$980645.79')
# ('Buzzbean', None, None, '$2240833.64')
# ('Bubbletube', None, None, '$1574302.74')
# ('Cogibox', None, None, '$1702000.13')
# ('Twitterlist', None, None, '$2918769.84')
# ('Photojam', None, None, '$2494032.10')
# ('Kayveo', None, None, '$2485801.90')
# ('Fivechat', None, None, '$666804.62')
# ('JumpXS', None, None, '$2878570.62')
# ('Bubblebox', None, None, '$2412086.15')
# ('Blogpad', None, None, '$1201360.51')
# ('Devpoint', None, None, '$166519.60')
# ('Quamba', None, None, '$90552.19')
# ('Voonder', None, None, '$1314525.01')
# ('Blogtag', None, None, '$1092486.49')
# ('Trupe', None, None, '$1057985.22')
# ('Babbleblab', None, None, '$1823116.04')
# ('Oyoba', None, None, '$163294.00')
# ('Innotype', None, None, '$484539.62')
# ('Einti', None, None, '$131878.44')
# ('Kayveo', None, None, '$837566.57')
# ('Gabvine', None, None, '$1766735.97')
# ('Linklinks', None, None, '$66926.31')
# ('Gevee', None, None, '$2008662.67')
# ('Ooba', None, None, '$178929.66')
# ('Rhynoodle', None, None, '$1706440.61')
# ('DabZ', None, None, '$2933159.68')
# ('Tekfly', None, None, '$306681.21')
# ('Realfire', None, None, '$2861948.83')
# ('Gigabox', None, None, '$1980257.90')
# ('Oyonder', None, None, '$47635.91')
# ('Plambee', None, None, '$428942.30')
# ('Flashdog', None, None, '$2586023.12')
# ('Thoughtblab', None, None, '$1064275.57')
# ('Jabberstorm', None, None, '$1384274.36')
# ('Twinder', None, None, '$1189772.67')
# ('Flipbug', None, None, '$337565.23')
# ('Yakidoo', None, None, '$528956.00')
# ('Vidoo', None, None, '$2780268.15')
# ('Blogtags', None, None, '$2974362.78')
# ('Quaxo', None, None, '$2068179.32')
# ('Gevee', None, None, '$1576002.12')
# ('Babbleset', None, None, '$818505.42')
# ('Jaxbean', None, None, '$2229101.14')
# ('Yacero', None, None, '$2015763.58')
# ('Camido', None, None, '$2937531.00')
# ('Vimbo', None, None, '$699101.99')
# ('Wikizz', None, None, '$2049259.12')
# ('Edgepulse', None, None, '$577472.13')
# ('Babblestorm', None, None, '$2177866.91')
# ('Yakidoo', None, None, '$568388.27')
# ('Buzzdog', None, None, '$282912.49')
# ('Meevee', None, None, '$2254324.56')
# ('Livepath', None, None, '$2178567.51')
# ('Eidel', None, None, '$1845525.42')
# ('Flipbug', None, None, '$686561.48')
# ('Tambee', None, None, '$2664140.23')
# ('Tagchat', None, None, '$2040884.93')
# ('Livepath', None, None, '$18053.47')
# ('Wikizz', None, None, '$2771066.30')
# ('Twitterworks', None, None, '$2668325.80')
# ('Topicstorm', None, None, '$2076470.15')
# ('Skinte', None, None, '$885674.82')
# ('Kwimbee', None, None, '$1007876.13')
# ('Jabbersphere', None, None, '$2424145.74')
# ('Leexo', None, None, '$1999299.48')
# ('Babbleblab', None, None, '$2204044.08')
# ('Kaymbo', None, None, '$193828.87')
# ('Wikido', None, None, '$2857758.46')
# ('Eabox', None, None, '$2392897.73')
# ('Feednation', None, None, '$273824.03')
# ('Jabbercube', None, None, '$1215607.39')
# ('Twimm', None, None, '$744529.20')
# ('Rhynyx', None, None, '$1382650.14')
# ('Tambee', None, None, '$784060.18')
# ('Voolith', None, None, '$2731028.29')
# ('Thoughtbeat', None, None, '$1717592.70')
# ('Voonix', None, None, '$1882656.92')
# ('Mydeo', None, None, '$364823.65')
# ('Nlounge', None, None, '$1354315.18')
# ('Edgeclub', None, None, '$1812398.16')
# ('Innojam', None, None, '$1055841.43')
# ('Photolist', None, None, '$2665442.29')
# ('Brightdog', None, None, '$1033941.19')
# ('Fiveclub', None, None, '$1059775.82')
# ('Chatterpoint', None, None, '$1073880.56')
# ('Oodoo', None, None, '$2887115.80')
# ('Skyndu', None, None, '$2128127.57')
# ('Buzzshare', None, None, '$2646304.41')
# ('Blogpad', None, None, '$2493303.56')
# ('Browsedrive', None, None, '$1475772.28')
# ('Fiveclub', None, None, '$2718273.78')
# ('Kazio', None, None, '$2851389.65')
# ('Jaxbean', None, None, '$435119.28')
# ('Blognation', None, None, '$2787566.92')
# ('Yadel', None, None, '$123585.37')
# ('Skibox', None, None, '$1292731.65')
# ('Blognation', None, None, '$1975830.56')
# ('Mymm', None, None, '$2792054.28')
# ('Kimia', None, None, '$2459890.43')
# ('JumpXS', None, None, '$836102.73')
# ('Miboo', None, None, '$2143265.30')
# ('Blogtag', None, None, '$2295838.76')
# ('Jabbersphere', None, None, '$1599775.64')
# ('Kanoodle', None, None, '$2424608.76')
# ('Skinte', None, None, '$2986560.45')
# ('Teklist', None, None, '$2174816.52')
# ('Eazzy', None, None, '$377347.29')
# ('Livepath', None, None, '$1083107.69')
# ('Buzzbean', None, None, '$1606205.87')
# ('Skajo', None, None, '$1409729.68')
# ('Kwilith', None, None, '$749588.03')
# ('Wordtune', None, None, '$1671782.16')
# ('Vinte', None, None, '$2752333.86')
# ('Devshare', None, None, '$800039.87')
# ('Muxo', None, None, '$2278878.18')
# ('Midel', None, None, '$880785.64')
# ('Bluejam', None, None, '$1384403.39')
# ('Twimbo', None, None, '$661143.06')
# ('Skibox', None, None, '$1479670.85')
# ('Aimbo', None, None, '$728599.70')
# ('Linktype', None, None, '$431954.74')
# ('Miboo', None, None, '$348975.71')
# ('Yozio', None, None, '$1459293.02')
# ('Rhynyx', None, None, '$2241158.85')
# ('Twinder', None, None, '$2649645.88')
# ('Devshare', None, None, '$342793.76')
# ('Digitube', None, None, '$2548600.12')
# ('Yotz', None, None, '$2581378.54')
# ('Quimba', None, None, '$140392.65')
# ('Agivu', None, None, '$1371725.48')
# ('Yata', None, None, '$805913.35')
# ('Skibox', None, None, '$586334.51')
# ('Bluejam', None, None, '$168169.93')
# ('Eimbee', None, None, '$743169.76')
# ('Skibox', None, None, '$599099.57')
# ('Kanoodle', None, None, '$2096187.68')
# ('Pixope', None, None, '$140426.20')
# ('Jetwire', None, None, '$2623740.72')
# ('Wordify', None, None, '$2054006.70')
# ('Divanoodle', None, None, '$1806187.87')
# ('Blogpad', None, None, '$2381273.66')
# ('Mydeo', None, None, '$1775832.32')
# ('Avamm', None, None, '$1348257.80')
# ('Kamba', None, None, '$2138318.37')
# ('Browseblab', None, None, '$2517199.74')
# ('Cogidoo', None, None, '$939603.15')
# ('Realmix', None, None, '$1224643.92')
# ('Quimba', None, None, '$2094290.94')
# ('Oyondu', None, None, '$1129377.65')
# ('Kwilith', None, None, '$322180.98')
# ('Shufflester', None, None, '$875871.68')
# ('Eazzy', None, None, '$2256526.69')
# ('Aimbo', None, None, '$1188570.45')
# ('Tekfly', None, None, '$1757975.70')
# ('Topdrive', None, None, '$2219850.65')
# ('Gevee', None, None, '$392200.86')

# %%
# Mutual instances: left join

conn = sqlite3.connect('company')
c = conn.cursor()

c.execute('''
SELECT
    client_number,
    company_orders.company_name,
    contact_first_name,
    contact_last_name
FROM
    company_orders
LEFT JOIN company_client_list ON company_client_list.company_name = company_orders.company_name;
''')

all_clients = []

for row in c.fetchall():
    clients.append(row)
    print(row)
    
conn.commit()
conn.close()
# Out:
# (184, 'Zoomcast', 'Ardyce', 'Stones')
# (None, 'Buzzbean', None, None)
# (None, 'Twitternation', None, None)
# (175, 'Topiczoom', 'Danyelle', 'Feldman')
# (182, 'Youbridge', 'Kylen', 'Daughton')
# (None, 'Yakijo', None, None)
# (None, 'Divavu', None, None)
# (None, 'Skajo', None, None)
# (174, 'Topicshots', 'Ajay', 'Hamley')
# (None, 'Kwideo', None, None)
# (None, 'Realbuzz', None, None)
# (178, 'Vinder', 'Kristien', 'Heaford')
# (None, 'Devcast', None, None)
# (None, 'Jamia', None, None)
# (154, 'Photofeed', 'Sharyl', 'Billany')
# (105, 'Brainbox', 'Jodie', 'Francombe')
# (None, 'Abatz', None, None)
# (158, 'Realcube', 'Paul', 'Egan')
# (None, 'Twimm', None, None)
# (None, 'BlogXS', None, None)
# (None, 'Yoveo', None, None)
# (None, 'Midel', None, None)
# (None, 'Janyx', None, None)
# (138, 'Kazu', 'Stacee', 'Langford')
# (None, 'Oyoba', None, None)
# (128, 'Flashpoint', 'Dilly', 'Brampton')
# (None, 'Kwideo', None, None)
# (None, 'Topicware', None, None)
# (None, 'Wikizz', None, None)
# (None, 'Thoughtworks', None, None)
# (None, 'Jaxworks', None, None)
# (None, 'Snaptags', None, None)
# (None, 'Yombu', None, None)
# (None, 'Skinder', None, None)
# (None, 'Shufflebeat', None, None)
# (None, 'Jamia', None, None)
# (None, 'Skinte', None, None)
# (None, 'Brainverse', None, None)
# (None, 'Eayo', None, None)
# (None, 'Edgepulse', None, None)
# (135, 'Jayo', 'Maressa', 'Pickthall')
# (None, 'Topiclounge', None, None)
# (None, 'Fanoodle', None, None)
# (175, 'Topiczoom', 'Danyelle', 'Feldman')
# (182, 'Youbridge', 'Kylen', 'Daughton')
# (None, 'Demimbu', None, None)
# (None, 'Kimia', None, None)
# (None, 'Zooxo', None, None)
# (None, 'Flipopia', None, None)
# (None, 'Wordpedia', None, None)
# (None, 'Skiptube', None, None)
# (None, 'Zoonoodle', None, None)
# (125, 'Feedfish', 'Jerri', 'Husthwaite')
# (None, 'Devcast', None, None)
# (None, 'Fliptune', None, None)
# (None, 'Yabox', None, None)
# (None, 'Midel', None, None)
# (175, 'Topiczoom', 'Danyelle', 'Feldman')
# (158, 'Realcube', 'Paul', 'Egan')
# (None, 'Tazzy', None, None)
# (154, 'Photofeed', 'Sharyl', 'Billany')
# (None, 'Skiptube', None, None)
# (None, 'Yodo', None, None)
# (None, 'Jetwire', None, None)
# (None, 'Cogidoo', None, None)
# (135, 'Jayo', 'Maressa', 'Pickthall')
# (None, 'Yakitri', None, None)
# (None, 'Linklinks', None, None)
# (144, 'Minyx', 'Stefania', 'Drews')
# (118, 'Dynabox', 'Paul', 'Vittori')
# (163, 'Riffpedia', 'Nickolas', 'Lambert')
# (None, 'Rhynyx', None, None)
# (147, 'Mynte', 'Darda', 'Iacapucci')
# (None, 'Edgeblab', None, None)
# (123, 'Fatz', 'Beitris', 'Jorioz')
# (None, 'Viva', None, None)
# (None, 'Yakijo', None, None)
# (None, 'Jetpulse', None, None)
# (None, 'Twinte', None, None)
# (None, 'Devpoint', None, None)
# (None, 'Fivechat', None, None)
# (None, 'Dabtype', None, None)
# (None, 'Feedfire', None, None)
# (None, 'Rooxo', None, None)
# (None, 'Photobean', None, None)
# (None, 'Thoughtworks', None, None)
# (None, 'Youfeed', None, None)
# (None, 'Skipfire', None, None)
# (None, 'Jabberbean', None, None)
# (170, 'Tagfeed', 'Dieter', 'Satchel')
# (171, 'Tagfeed', 'Blakelee', "O'Scanlon")
# (None, 'Zooxo', None, None)
# (None, 'Shufflester', None, None)
# (120, 'Eare', 'Bel', 'Caughan')
# (139, 'Leenti', 'Leona', 'Murricanes')
# (None, 'Divavu', None, None)
# (176, 'Twitterbridge', 'Harmonia', "O'Hederscoll")
# (None, 'DabZ', None, None)
# (None, 'Trupe', None, None)
# (None, 'Fanoodle', None, None)
# (None, 'Meezzy', None, None)
# (None, 'Vimbo', None, None)
# (None, 'Tazzy', None, None)
# (None, 'Chatterpoint', None, None)
# (None, 'Trilia', None, None)
# (None, 'Twinder', None, None)
# (None, 'Rhynyx', None, None)
# (None, 'Jabbercube', None, None)
# (153, 'Photobug', 'Pietra', 'McDill')
# (None, 'Zooxo', None, None)
# (None, 'Jaloo', None, None)
# (None, 'Twitterbeat', None, None)
# (None, 'Lajo', None, None)
# (183, 'Youtags', 'Traver', 'Beckford')
# (None, 'Fliptune', None, None)
# (None, 'Oyoba', None, None)
# (None, 'Realbridge', None, None)
# (133, 'Jatri', 'Winonah', 'Samson')
# (134, 'Jatri', 'Niccolo', 'Bram')
# (None, 'Mydo', None, None)
# (None, 'Tanoodle', None, None)
# (None, 'Agimba', None, None)
# (None, 'Demimbu', None, None)
# (None, 'Mudo', None, None)
# (119, 'Eadel', 'Pearline', 'Brigham')
# (None, 'Dabjam', None, None)
# (None, 'Mudo', None, None)
# (None, 'Innojam', None, None)
# (None, 'Linklinks', None, None)
# (None, 'Skajo', None, None)
# (None, 'Jaxnation', None, None)
# (None, 'Edgetag', None, None)
# (None, 'Flashspan', None, None)
# (None, 'BlogXS', None, None)
# (109, 'Bubblemix', 'Orelle', 'Rean')
# (181, 'Yamia', 'Ilario', 'Keedy')
# (181, 'Yamia', 'Ilario', 'Keedy')
# (None, 'Fanoodle', None, None)
# (None, 'Twitterworks', None, None)
# (None, 'Divavu', None, None)
# (None, 'Tagcat', None, None)
# (None, 'Feednation', None, None)
# (None, 'Plajo', None, None)
# (None, 'Tagcat', None, None)
# (137, 'Katz', 'Duncan', 'Hanwright')
# (None, 'Janyx', None, None)
# (None, 'Nlounge', None, None)
# (177, 'Twiyo', 'Desdemona', 'McKeever')
# (None, 'Aimbu', None, None)
# (None, 'Devify', None, None)
# (119, 'Eadel', 'Pearline', 'Brigham')
# (None, 'Jetwire', None, None)
# (130, 'Gabspot', 'Abba', 'Marson')
# (177, 'Twiyo', 'Desdemona', 'McKeever')
# (None, 'Geba', None, None)
# (None, 'Riffwire', None, None)
# (None, 'Youspan', None, None)
# (165, 'Skaboo', 'Mord', 'Cook')
# (None, 'Browseblab', None, None)
# (None, 'Skinix', None, None)
# (115, 'Demivee', 'Adamo', 'Matuszinski')
# (None, 'Eidel', None, None)
# (158, 'Realcube', 'Paul', 'Egan')
# (None, 'Brightdog', None, None)
# (None, 'Skiba', None, None)
# (None, 'Chatterbridge', None, None)
# (None, 'Meedoo', None, None)
# (None, 'Browseblab', None, None)
# (None, 'Quatz', None, None)
# (None, 'Browsezoom', None, None)
# (135, 'Jayo', 'Maressa', 'Pickthall')
# (None, 'Jaxnation', None, None)
# (None, 'Voolith', None, None)
# (None, 'Chatterbridge', None, None)
# (115, 'Demivee', 'Adamo', 'Matuszinski')
# (None, 'Flashspan', None, None)
# (None, 'Tagcat', None, None)
# (None, 'Dabjam', None, None)
# (173, 'Thoughtstorm', 'Bunni', 'Breen')
# (153, 'Photobug', 'Pietra', 'McDill')
# (None, 'Vinte', None, None)
# (None, 'Jamia', None, None)
# (147, 'Mynte', 'Darda', 'Iacapucci')
# (179, 'Voonyx', 'Ajay', 'Wince')
# (None, 'Skyba', None, None)
# (158, 'Realcube', 'Paul', 'Egan')
# (None, 'Flipbug', None, None)
# (None, 'Brightbean', None, None)
# (None, 'Realfire', None, None)
# (169, 'Skyvu', 'Rey', 'Salzen')
# (173, 'Thoughtstorm', 'Bunni', 'Breen')
# (None, 'Blogspan', None, None)
# (None, 'Yozio', None, None)
# (None, 'Babblestorm', None, None)
# (None, 'Talane', None, None)
# (None, 'Skajo', None, None)
# (None, 'Fiveclub', None, None)
# (None, 'Viva', None, None)
# (None, 'Wordpedia', None, None)
# (None, 'Izio', None, None)
# (102, 'Avamba', 'Deb', 'Petruszka')
# (None, 'Vipe', None, None)
# (None, 'Divavu', None, None)
# (123, 'Fatz', 'Beitris', 'Jorioz')
# (None, 'Devify', None, None)
# (None, 'Gigashots', None, None)
# (None, 'Edgeblab', None, None)
# (None, 'Dabjam', None, None)
# (None, 'Tagopia', None, None)
# (None, 'Skajo', None, None)
# (None, 'Camido', None, None)
# (147, 'Mynte', 'Darda', 'Iacapucci')
# (None, 'Talane', None, None)
# (None, 'Divanoodle', None, None)
# (139, 'Leenti', 'Leona', 'Murricanes')
# (105, 'Brainbox', 'Jodie', 'Francombe')
# (None, 'Shuffletag', None, None)
# (None, 'Voomm', None, None)
# (None, 'Mydeo', None, None)
# (None, 'Kayveo', None, None)
# (161, 'Rhyloo', 'Sasha', 'Clewley')
# (None, 'Pixope', None, None)
# (None, 'Trudeo', None, None)
# (165, 'Skaboo', 'Mord', 'Cook')
# (None, 'Trilith', None, None)
# (None, 'Quire', None, None)
# (None, 'Leexo', None, None)
# (None, 'Fliptune', None, None)
# (None, 'Yozio', None, None)
# (None, 'Thoughtbeat', None, None)
# (174, 'Topicshots', 'Ajay', 'Hamley')
# (None, 'Vimbo', None, None)
# (None, 'Skinix', None, None)
# (None, 'Quatz', None, None)
# (123, 'Fatz', 'Beitris', 'Jorioz')
# (None, 'Tazzy', None, None)
# (None, 'Feedspan', None, None)
# (None, 'Centimia', None, None)
# (None, 'Dabshots', None, None)
# (141, 'Livetube', 'Teador', 'MacPike')
# (None, 'Mymm', None, None)
# (141, 'Livetube', 'Teador', 'MacPike')
# (160, 'Rhybox', 'Margarita', 'Philippault')
# (None, 'Devpulse', None, None)
# (None, 'Devpulse', None, None)
# (154, 'Photofeed', 'Sharyl', 'Billany')
# (None, 'Voolith', None, None)
# (131, 'Gabtype', 'Briney', 'Robinet')
# (None, 'Trilia', None, None)
# (None, 'Skinder', None, None)
# (None, 'Innotype', None, None)
# (None, 'Voomm', None, None)
# (None, 'Lajo', None, None)
# (None, 'Trudeo', None, None)
# (None, 'Youspan', None, None)
# (None, 'Edgepulse', None, None)
# (None, 'Bluejam', None, None)
# (None, 'Skinder', None, None)
# (None, 'Divavu', None, None)
# (147, 'Mynte', 'Darda', 'Iacapucci')
# (166, 'Skalith', 'Mandi', 'Syseland')
# (None, 'Wikizz', None, None)
# (None, 'Quimm', None, None)
# (None, 'Yakitri', None, None)
# (None, 'Trudoo', None, None)
# (None, 'Camido', None, None)
# (None, 'Jaxspan', None, None)
# (None, 'Zoomdog', None, None)
# (None, 'Centizu', None, None)
# (None, 'Cogibox', None, None)
# (153, 'Photobug', 'Pietra', 'McDill')
# (None, 'Eabox', None, None)
# (None, 'Youspan', None, None)
# (None, 'Linktype', None, None)
# (137, 'Katz', 'Duncan', 'Hanwright')
# (None, 'Eimbee', None, None)
# (None, 'Yotz', None, None)
# (None, 'Fanoodle', None, None)
# (None, 'Gigashots', None, None)
# (None, 'Blogpad', None, None)
# (None, 'Wikivu', None, None)
# (None, 'Jabbercube', None, None)
# (151, 'Oozz', 'Marje', 'Weldon')
# (None, 'Quimba', None, None)
# (None, 'Jaxworks', None, None)
# (None, 'Trupe', None, None)
# (None, 'Abatz', None, None)
# (None, 'Topicblab', None, None)
# (None, 'Dabjam', None, None)
# (154, 'Photofeed', 'Sharyl', 'Billany')
# (158, 'Realcube', 'Paul', 'Egan')
# (None, 'Tagchat', None, None)
# (118, 'Dynabox', 'Paul', 'Vittori')
# (None, 'Dabjam', None, None)
# (None, 'Twimm', None, None)
# (None, 'Zoonder', None, None)
# (159, 'Reallinks', 'Brietta', 'Hazel')
# (170, 'Tagfeed', 'Dieter', 'Satchel')
# (171, 'Tagfeed', 'Blakelee', "O'Scanlon")
# (160, 'Rhybox', 'Margarita', 'Philippault')
# (None, 'Shufflebeat', None, None)
# (147, 'Mynte', 'Darda', 'Iacapucci')
# (None, 'Flipopia', None, None)
# (None, 'Skibox', None, None)
# (None, 'Skippad', None, None)
# (None, 'Vitz', None, None)
# (None, 'Dynazzy', None, None)
# (None, 'Yombu', None, None)
# (None, 'Tagopia', None, None)
# (173, 'Thoughtstorm', 'Bunni', 'Breen')
# (None, 'Roomm', None, None)
# (None, 'Mymm', None, None)
# (None, 'Skimia', None, None)
# (138, 'Kazu', 'Stacee', 'Langford')
# (158, 'Realcube', 'Paul', 'Egan')
# (107, 'Browsebug', 'Tobie', 'Arran')
# (None, 'Voonte', None, None)
# (None, 'Eayo', None, None)
# (156, 'Quinu', 'Amitie', 'Wybrew')
# (None, 'Ooba', None, None)
# (None, 'Yakijo', None, None)
# (None, 'Tagopia', None, None)
# (None, 'Wordtune', None, None)
# (114, 'Dazzlesphere', 'Orlan', 'Pynner')
# (None, 'Fivebridge', None, None)
# (None, 'Digitube', None, None)
# (None, 'Flipbug', None, None)
# (None, 'Dynava', None, None)
# (None, 'Ailane', None, None)
# (None, 'Trudeo', None, None)
# (None, 'Kwilith', None, None)
# (None, 'Viva', None, None)
# (154, 'Photofeed', 'Sharyl', 'Billany')
# (None, 'Pixope', None, None)
# (None, 'Devpoint', None, None)
# (None, 'Fivechat', None, None)
# (None, 'Youopia', None, None)
# (None, 'Photolist', None, None)
# (None, 'Devshare', None, None)
# (None, 'Meevee', None, None)
# (None, 'Viva', None, None)
# (None, 'Lazzy', None, None)
# (None, 'Rooxo', None, None)
# (None, 'Skippad', None, None)
# (None, 'Jabbersphere', None, None)
# (None, 'Twinder', None, None)
# (None, 'Quaxo', None, None)
# (143, 'Meetz', 'Alphonse', 'Warboy')
# (None, 'Kwilith', None, None)
# (None, 'Centizu', None, None)
# (None, 'Zoombox', None, None)
# (None, 'Zava', None, None)
# (None, 'Oyoba', None, None)
# (None, 'Oyoyo', None, None)
# (None, 'Photolist', None, None)
# (None, 'Babbleblab', None, None)
# (None, 'Lazzy', None, None)
# (None, 'Twitterworks', None, None)
# (143, 'Meetz', 'Alphonse', 'Warboy')
# (None, 'Flashset', None, None)
# (176, 'Twitterbridge', 'Harmonia', "O'Hederscoll")
# (None, 'Divanoodle', None, None)
# (129, 'Flipstorm', 'Candace', 'Pantling')
# (126, 'Feedmix', 'Enos', 'Marciek')
# (122, 'Edgewire', 'Merell', 'Meake')
# (None, 'Edgetag', None, None)
# (None, 'Edgeclub', None, None)
# (None, 'Blogspan', None, None)
# (None, 'Teklist', None, None)
# (None, 'Twitternation', None, None)
# (None, 'Buzzdog', None, None)
# (157, 'Realblab', 'Lilia', 'Point')
# (None, 'Topicblab', None, None)
# (None, 'Dabfeed', None, None)
# (149, 'Npath', 'Farris', 'Tulk')
# (None, 'Skidoo', None, None)
# (183, 'Youtags', 'Traver', 'Beckford')
# (None, 'Linktype', None, None)
# (155, 'Pixoboo', 'Davine', 'Trenholme')
# (None, 'Gigazoom', None, None)
# (None, 'Thoughtbeat', None, None)
# (None, 'Blogtags', None, None)
# (None, 'Camido', None, None)
# (None, 'Quimba', None, None)
# (None, 'Livepath', None, None)
# (140, 'Linkbuzz', 'Hersh', 'Goodrick')
# (None, 'Cogidoo', None, None)
# (None, 'Twitternation', None, None)
# (None, 'Buzzbean', None, None)
# (159, 'Reallinks', 'Brietta', 'Hazel')
# (None, 'Jabbercube', None, None)
# (None, 'Browsezoom', None, None)
# (None, 'Topiclounge', None, None)
# (None, 'Yodo', None, None)
# (None, 'Wordtune', None, None)
# (None, 'Realbuzz', None, None)
# (None, 'Yakidoo', None, None)
# (None, 'Twimm', None, None)
# (None, 'Tagtune', None, None)
# (None, 'Yacero', None, None)
# (None, 'Buzzdog', None, None)
# (101, 'Aivee', 'Melli', 'Bartolomeotti')
# (None, 'Bluejam', None, None)
# (None, 'Oyonder', None, None)
# (None, 'Zoovu', None, None)
# (None, 'Plambee', None, None)
# (None, 'Gabcube', None, None)
# (None, 'Eimbee', None, None)
# (None, 'Oyondu', None, None)
# (111, 'Cogilith', 'Kellia', 'Robinson')
# (None, 'Jetwire', None, None)
# (None, 'Centimia', None, None)
# (None, 'Fivechat', None, None)
# (100, 'Ainyx', 'Timmie', 'Axston')
# (None, 'Tazzy', None, None)
# (None, 'Gabtune', None, None)
# (None, 'Thoughtmix', None, None)
# (None, 'Jaxnation', None, None)
# (None, 'Viva', None, None)
# (None, 'Kwimbee', None, None)
# (None, 'Rhynoodle', None, None)
# (None, 'Skinte', None, None)
# (None, 'Wordpedia', None, None)
# (108, 'Browsecat', 'Mikaela', 'Doddridge')
# (None, 'Linktype', None, None)
# (123, 'Fatz', 'Beitris', 'Jorioz')
# (None, 'Thoughtblab', None, None)
# (None, 'Aimbo', None, None)
# (137, 'Katz', 'Duncan', 'Hanwright')
# (None, 'Eidel', None, None)
# (155, 'Pixoboo', 'Davine', 'Trenholme')
# (None, 'Jabberstorm', None, None)
# (None, 'Meeveo', None, None)
# (None, 'Youfeed', None, None)
# (None, 'Twimbo', None, None)
# (117, 'Divape', 'Lorine', 'Jarry')
# (None, 'Skinte', None, None)
# (None, 'Shufflebeat', None, None)
# (None, 'Devpoint', None, None)
# (None, 'Realfire', None, None)
# (None, 'Edgepulse', None, None)
# (None, 'Mybuzz', None, None)
# (None, 'Gigazoom', None, None)
# (129, 'Flipstorm', 'Candace', 'Pantling')
# (None, 'Quaxo', None, None)
# (177, 'Twiyo', 'Desdemona', 'McKeever')
# (None, 'Wikizz', None, None)
# (None, 'Brainsphere', None, None)
# (135, 'Jayo', 'Maressa', 'Pickthall')
# (None, 'Tagchat', None, None)
# (None, 'Quamba', None, None)
# (None, 'Zoonder', None, None)
# (None, 'Tanoodle', None, None)
# (None, 'Blognation', None, None)
# (None, 'Nlounge', None, None)
# (None, 'Eayo', None, None)
# (None, 'Tagopia', None, None)
# (158, 'Realcube', 'Paul', 'Egan')
# (None, 'Wordware', None, None)
# (None, 'Vinte', None, None)
# (None, 'Lazzy', None, None)
# (166, 'Skalith', 'Mandi', 'Syseland')
# (148, 'Myworks', 'Magda', 'Slator')
# (None, 'Kimia', None, None)
# (None, 'Centimia', None, None)
# (140, 'Linkbuzz', 'Hersh', 'Goodrick')
# (None, 'Skipfire', None, None)
# (None, 'Feedfire', None, None)
# (106, 'Brainlounge', 'Dyana', 'Mingame')
# (None, 'Kwimbee', None, None)
# (None, 'Voonder', None, None)
# (None, 'Camimbo', None, None)
# (None, 'Dabshots', None, None)
# (None, 'Jabberstorm', None, None)
# (None, 'Jamia', None, None)
# (None, 'Trupe', None, None)
# (None, 'Bubbletube', None, None)
# (None, 'Quatz', None, None)
# (None, 'Yacero', None, None)
# (178, 'Vinder', 'Kristien', 'Heaford')
# (None, 'Fadeo', None, None)
# (None, 'Twitterlist', None, None)
# (None, 'JumpXS', None, None)
# (None, 'Camido', None, None)
# (None, 'Plambee', None, None)
# (None, 'Thoughtmix', None, None)
# (None, 'Bluejam', None, None)
# (141, 'Livetube', 'Teador', 'MacPike')
# (None, 'Oyonder', None, None)
# (139, 'Leenti', 'Leona', 'Murricanes')
# (None, 'Oyoloo', None, None)
# (None, 'Centimia', None, None)
# (None, 'Babblestorm', None, None)
# (None, 'Ozu', None, None)
# (149, 'Npath', 'Farris', 'Tulk')
# (None, 'Oloo', None, None)
# (None, 'Twitterwire', None, None)
# (None, 'Oyoba', None, None)
# (138, 'Kazu', 'Stacee', 'Langford')
# (None, 'Jaxworks', None, None)
# (None, 'Realbuzz', None, None)
# (None, 'Meeveo', None, None)
# (164, 'Roombo', 'Rorie', 'Frissell')
# (None, 'Miboo', None, None)
# (None, 'Skiba', None, None)
# (None, 'Devpulse', None, None)
# (None, 'Shufflester', None, None)
# (None, 'Fliptune', None, None)
# (None, 'Bluezoom', None, None)
# (None, 'Thoughtblab', None, None)
# (None, 'Tagchat', None, None)
# (None, 'Ntag', None, None)
# (None, 'Oyoloo', None, None)
# (182, 'Youbridge', 'Kylen', 'Daughton')
# (None, 'Quaxo', None, None)
# (131, 'Gabtype', 'Briney', 'Robinet')
# (None, 'Skibox', None, None)
# (None, 'Twitternation', None, None)
# (None, 'Thoughtbeat', None, None)
# (182, 'Youbridge', 'Kylen', 'Daughton')
# (157, 'Realblab', 'Lilia', 'Point')
# (None, 'Jamia', None, None)
# (None, 'Buzzbean', None, None)
# (103, 'Avaveo', 'Dick', 'Borgnol')
# (None, 'Browseblab', None, None)
# (160, 'Rhybox', 'Margarita', 'Philippault')
# (None, 'Yabox', None, None)
# (155, 'Pixoboo', 'Davine', 'Trenholme')
# (None, 'Talane', None, None)
# (None, 'Eimbee', None, None)
# (None, 'Leexo', None, None)
# (183, 'Youtags', 'Traver', 'Beckford')
# (None, 'Ntags', None, None)
# (149, 'Npath', 'Farris', 'Tulk')
# (None, 'Bluejam', None, None)
# (None, 'Eimbee', None, None)
# (170, 'Tagfeed', 'Dieter', 'Satchel')
# (171, 'Tagfeed', 'Blakelee', "O'Scanlon")
# (None, 'Twitterbeat', None, None)
# (None, 'Gevee', None, None)
# (141, 'Livetube', 'Teador', 'MacPike')
# (None, 'Centimia', None, None)
# (None, 'Jazzy', None, None)
# (None, 'Leexo', None, None)
# (None, 'Bubbletube', None, None)
# (None, 'Buzzbean', None, None)
# (None, 'Mydo', None, None)
# (None, 'Miboo', None, None)
# (None, 'Quire', None, None)
# (None, 'Browseblab', None, None)
# (164, 'Roombo', 'Rorie', 'Frissell')
# (None, 'Skinder', None, None)
# (None, 'Jabberbean', None, None)
# (None, 'Janyx', None, None)
# (None, 'Blognation', None, None)
# (None, 'Trunyx', None, None)
# (None, 'Ntag', None, None)
# (None, 'Yodoo', None, None)
# (None, 'Devshare', None, None)
# (None, 'Blogpad', None, None)
# (None, 'Bubblebox', None, None)
# (None, 'Devshare', None, None)
# (None, 'Skyble', None, None)
# (112, 'Dablist', 'Zebulen', 'Dyett')
# (151, 'Oozz', 'Marje', 'Weldon')
# (None, 'Zoovu', None, None)
# (None, 'Devshare', None, None)
# (None, 'Quimm', None, None)
# (None, 'Bluezoom', None, None)
# (None, 'Yodel', None, None)
# (None, 'Skyndu', None, None)
# (None, 'Fivebridge', None, None)
# (145, 'Mita', 'Kassandra', 'Marks')
# (None, 'Digitube', None, None)
# (None, 'Meezzy', None, None)
# (None, 'Gigabox', None, None)
# (None, 'Devpoint', None, None)
# (None, 'Trudoo', None, None)
# (None, 'Ooba', None, None)
# (None, 'Tavu', None, None)
# (None, 'Shuffledrive', None, None)
# (None, 'Oyoloo', None, None)
# (None, 'Flashdog', None, None)
# (None, 'Aimbo', None, None)
# (None, 'Yodo', None, None)
# (162, 'Riffpath', 'Rayna', 'Lepere')
# (None, 'Babbleblab', None, None)
# (103, 'Avaveo', 'Dick', 'Borgnol')
# (164, 'Roombo', 'Rorie', 'Frissell')
# (152, 'Oyope', 'Jenny', 'Curle')
# (None, 'Gigashots', None, None)
# (None, 'Rhynyx', None, None)
# (122, 'Edgewire', 'Merell', 'Meake')
# (None, 'Quamba', None, None)
# (None, 'Bubblebox', None, None)
# (None, 'Vitz', None, None)
# (None, 'Babblestorm', None, None)
# (None, 'Aimbu', None, None)
# (None, 'Brightbean', None, None)
# (None, 'Mydo', None, None)
# (None, 'Wordpedia', None, None)
# (None, 'Vipe', None, None)
# (None, 'Realpoint', None, None)
# (None, 'Fliptune', None, None)
# (182, 'Youbridge', 'Kylen', 'Daughton')
# (None, 'Linktype', None, None)
# (None, 'Tagcat', None, None)
# (None, 'Thoughtblab', None, None)
# (None, 'Topicware', None, None)
# (None, 'Babbleset', None, None)
# (None, 'Voonte', None, None)
# (None, 'Quire', None, None)
# (None, 'Latz', None, None)
# (172, 'Tazz', 'Dom', 'Cremins')
# (None, 'Blognation', None, None)
# (None, 'Muxo', None, None)
# (None, 'Izio', None, None)
# (None, 'Edgepulse', None, None)
# (114, 'Dazzlesphere', 'Orlan', 'Pynner')
# (None, 'Vidoo', None, None)
# (121, 'Edgeify', 'Katina', 'Orrocks')
# (None, 'Brightdog', None, None)
# (None, 'Zoomzone', None, None)
# (183, 'Youtags', 'Traver', 'Beckford')
# (None, 'Gigabox', None, None)
# (None, 'Topicware', None, None)
# (None, 'Wordify', None, None)
# (None, 'Demimbu', None, None)
# (109, 'Bubblemix', 'Orelle', 'Rean')
# (124, 'Feedbug', 'Andee', 'Cramp')
# (None, 'Janyx', None, None)
# (None, 'Dynava', None, None)
# (175, 'Topiczoom', 'Danyelle', 'Feldman')
# (153, 'Photobug', 'Pietra', 'McDill')
# (None, 'Realpoint', None, None)
# (None, 'Flipopia', None, None)
# (None, 'Yakitri', None, None)
# (None, 'Gabtune', None, None)
# (None, 'Tagpad', None, None)
# (None, 'Jamia', None, None)
# (None, 'Topdrive', None, None)
# (None, 'Flipopia', None, None)
# (132, 'InnoZ', 'Nicoline', 'Milmore')
# (None, 'Feednation', None, None)
# (None, 'Eimbee', None, None)
# (None, 'Devcast', None, None)
# (None, 'Trudoo', None, None)
# (None, 'Meezzy', None, None)
# (None, 'Kimia', None, None)
# (None, 'Ntags', None, None)
# (181, 'Yamia', 'Ilario', 'Keedy')
# (None, 'Trupe', None, None)
# (None, 'Aimbu', None, None)
# (None, 'Pixope', None, None)
# (None, 'Aibox', None, None)
# (None, 'Trunyx', None, None)
# (167, 'Skilith', 'Ossie', 'Moreno')
# (141, 'Livetube', 'Teador', 'MacPike')
# (None, 'Ailane', None, None)
# (None, 'Latz', None, None)
# (None, 'Gigabox', None, None)
# (105, 'Brainbox', 'Jodie', 'Francombe')
# (None, 'Oyoba', None, None)
# (None, 'Talane', None, None)
# (None, 'Fanoodle', None, None)
# (None, 'Voonder', None, None)
# (None, 'Yodoo', None, None)
# (153, 'Photobug', 'Pietra', 'McDill')
# (None, 'Buzzdog', None, None)
# (111, 'Cogilith', 'Kellia', 'Robinson')
# (None, 'Photobean', None, None)
# (None, 'Camido', None, None)
# (None, 'Quire', None, None)
# (None, 'Jabbercube', None, None)
# (121, 'Edgeify', 'Katina', 'Orrocks')
# (None, 'Voonder', None, None)
# (None, 'Fliptune', None, None)
# (None, 'Jaxnation', None, None)
# (161, 'Rhyloo', 'Sasha', 'Clewley')
# (142, 'Meejo', 'Abran', 'Antoniat')
# (174, 'Topicshots', 'Ajay', 'Hamley')
# (None, 'Muxo', None, None)
# (None, 'Jaxspan', None, None)
# (None, 'Jaxbean', None, None)
# (None, 'Bubbletube', None, None)
# (None, 'Twitternation', None, None)
# (None, 'Brainverse', None, None)
# (None, 'Feednation', None, None)
# (None, 'Realmix', None, None)
# (None, 'Meedoo', None, None)
# (None, 'Livefish', None, None)
# (None, 'Skyndu', None, None)
# (None, 'Skinder', None, None)
# (None, 'Voolith', None, None)
# (None, 'Flipopia', None, None)
# (None, 'Riffwire', None, None)
# (None, 'Oyoba', None, None)
# (None, 'Abatz', None, None)
# (181, 'Yamia', 'Ilario', 'Keedy')
# (None, 'Meevee', None, None)
# (None, 'Topicware', None, None)
# (None, 'Lajo', None, None)
# (None, 'Digitube', None, None)
# (None, 'Blogtag', None, None)
# (108, 'Browsecat', 'Mikaela', 'Doddridge')
# (None, 'Thoughtbeat', None, None)
# (None, 'Twimbo', None, None)
# (None, 'Ooba', None, None)
# (None, 'Jabbersphere', None, None)
# (None, 'Yakitri', None, None)
# (None, 'Quatz', None, None)
# (None, 'Browseblab', None, None)
# (None, 'Browseblab', None, None)
# (None, 'Yakidoo', None, None)
# (None, 'Trunyx', None, None)
# (133, 'Jatri', 'Winonah', 'Samson')
# (134, 'Jatri', 'Niccolo', 'Bram')
# (None, 'Skyndu', None, None)
# (None, 'Meeveo', None, None)
# (None, 'Skimia', None, None)
# (132, 'InnoZ', 'Nicoline', 'Milmore')
# (161, 'Rhyloo', 'Sasha', 'Clewley')
# (151, 'Oozz', 'Marje', 'Weldon')
# (None, 'Thoughtbeat', None, None)
# (None, 'Quimba', None, None)
# (None, 'Browseblab', None, None)
# (137, 'Katz', 'Duncan', 'Hanwright')
# (None, 'Rhycero', None, None)
# (None, 'Devcast', None, None)
# (None, 'Ailane', None, None)
# (None, 'Shufflebeat', None, None)
# (None, 'Topicblab', None, None)
# (None, 'Abata', None, None)
# (143, 'Meetz', 'Alphonse', 'Warboy')
# (176, 'Twitterbridge', 'Harmonia', "O'Hederscoll")
# (None, 'Meevee', None, None)
# (None, 'Photojam', None, None)
# (None, 'Thoughtblab', None, None)
# (None, 'Viva', None, None)
# (None, 'Rhynyx', None, None)
# (137, 'Katz', 'Duncan', 'Hanwright')
# (144, 'Minyx', 'Stefania', 'Drews')
# (None, 'Devpoint', None, None)
# (None, 'Kwilith', None, None)
# (None, 'Gevee', None, None)
# (None, 'Skinder', None, None)
# (None, 'Browseblab', None, None)
# (None, 'Photolist', None, None)
# (123, 'Fatz', 'Beitris', 'Jorioz')
# (None, 'Roomm', None, None)
# (None, 'Kimia', None, None)
# (None, 'Oodoo', None, None)
# (None, 'Quire', None, None)
# (None, 'Cogidoo', None, None)
# (152, 'Oyope', 'Jenny', 'Curle')
# (None, 'Cogidoo', None, None)
# (None, 'Buzzshare', None, None)
# (None, 'Wikizz', None, None)
# (None, 'Yambee', None, None)
# (None, 'Wikido', None, None)
# (None, 'Voonix', None, None)
# (168, 'Skipstorm', 'Dela', 'Dashkovich')
# (None, 'Camido', None, None)
# (None, 'Eamia', None, None)
# (156, 'Quinu', 'Amitie', 'Wybrew')
# (None, 'Kayveo', None, None)
# (128, 'Flashpoint', 'Dilly', 'Brampton')
# (None, 'Youspan', None, None)
# (None, 'Photospace', None, None)
# (None, 'Devpulse', None, None)
# (104, 'Babbleopia', 'Bendick', 'Sawkin')
# (166, 'Skalith', 'Mandi', 'Syseland')
# (None, 'Yakijo', None, None)
# (None, 'Divavu', None, None)
# (141, 'Livetube', 'Teador', 'MacPike')
# (None, 'Tagopia', None, None)
# (None, 'Abata', None, None)
# (None, 'Rhynyx', None, None)
# (None, 'Eazzy', None, None)
# (None, 'Kimia', None, None)
# (None, 'Camido', None, None)
# (None, 'Zoonoodle', None, None)
# (158, 'Realcube', 'Paul', 'Egan')
# (None, 'Voolia', None, None)
# (None, 'Eabox', None, None)
# (None, 'Quatz', None, None)
# (None, 'Quimm', None, None)
# (None, 'Browseblab', None, None)
# (None, 'Devshare', None, None)
# (None, 'Photospace', None, None)
# (None, 'Kwilith', None, None)
# (118, 'Dynabox', 'Paul', 'Vittori')
# (178, 'Vinder', 'Kristien', 'Heaford')
# (None, 'Gigazoom', None, None)
# (None, 'Twitterlist', None, None)
# (None, 'Babbleblab', None, None)
# (None, 'Blognation', None, None)
# (None, 'Realbuzz', None, None)
# (None, 'Yabox', None, None)
# (None, 'Realbridge', None, None)
# (None, 'Buzzbean', None, None)
# (None, 'Bubbletube', None, None)
# (None, 'Cogibox', None, None)
# (152, 'Oyope', 'Jenny', 'Curle')
# (None, 'Twitterlist', None, None)
# (None, 'Photojam', None, None)
# (None, 'Kayveo', None, None)
# (None, 'Fivechat', None, None)
# (None, 'JumpXS', None, None)
# (None, 'Bubblebox', None, None)
# (None, 'Blogpad', None, None)
# (None, 'Devpoint', None, None)
# (118, 'Dynabox', 'Paul', 'Vittori')
# (None, 'Quamba', None, None)
# (None, 'Voonder', None, None)
# (None, 'Blogtag', None, None)
# (None, 'Trupe', None, None)
# (141, 'Livetube', 'Teador', 'MacPike')
# (158, 'Realcube', 'Paul', 'Egan')
# (None, 'Babbleblab', None, None)
# (174, 'Topicshots', 'Ajay', 'Hamley')
# (147, 'Mynte', 'Darda', 'Iacapucci')
# (None, 'Oyoba', None, None)
# (101, 'Aivee', 'Melli', 'Bartolomeotti')
# (None, 'Innotype', None, None)
# (None, 'Einti', None, None)
# (None, 'Kayveo', None, None)
# (None, 'Gabvine', None, None)
# (None, 'Linklinks', None, None)
# (None, 'Gevee', None, None)
# (None, 'Ooba', None, None)
# (None, 'Rhynoodle', None, None)
# (None, 'DabZ', None, None)
# (None, 'Tekfly', None, None)
# (None, 'Realfire', None, None)
# (None, 'Gigabox', None, None)
# (None, 'Oyonder', None, None)
# (179, 'Voonyx', 'Ajay', 'Wince')
# (178, 'Vinder', 'Kristien', 'Heaford')
# (None, 'Plambee', None, None)
# (None, 'Flashdog', None, None)
# (None, 'Thoughtblab', None, None)
# (135, 'Jayo', 'Maressa', 'Pickthall')
# (None, 'Jabberstorm', None, None)
# (100, 'Ainyx', 'Timmie', 'Axston')
# (None, 'Twinder', None, None)
# (None, 'Flipbug', None, None)
# (None, 'Yakidoo', None, None)
# (None, 'Vidoo', None, None)
# (None, 'Blogtags', None, None)
# (None, 'Quaxo', None, None)
# (None, 'Gevee', None, None)
# (None, 'Babbleset', None, None)
# (None, 'Jaxbean', None, None)
# (None, 'Yacero', None, None)
# (None, 'Camido', None, None)
# (None, 'Vimbo', None, None)
# (None, 'Wikizz', None, None)
# (None, 'Edgepulse', None, None)
# (None, 'Babblestorm', None, None)
# (None, 'Yakidoo', None, None)
# (None, 'Buzzdog', None, None)
# (None, 'Meevee', None, None)
# (None, 'Livepath', None, None)
# (None, 'Eidel', None, None)
# (None, 'Flipbug', None, None)
# (176, 'Twitterbridge', 'Harmonia', "O'Hederscoll")
# (154, 'Photofeed', 'Sharyl', 'Billany')
# (None, 'Tambee', None, None)
# (None, 'Tagchat', None, None)
# (None, 'Livepath', None, None)
# (None, 'Wikizz', None, None)
# (None, 'Twitterworks', None, None)
# (None, 'Topicstorm', None, None)
# (160, 'Rhybox', 'Margarita', 'Philippault')
# (None, 'Skinte', None, None)
# (None, 'Kwimbee', None, None)
# (None, 'Jabbersphere', None, None)
# (None, 'Leexo', None, None)
# (None, 'Babbleblab', None, None)
# (None, 'Kaymbo', None, None)
# (None, 'Wikido', None, None)
# (None, 'Eabox', None, None)
# (147, 'Mynte', 'Darda', 'Iacapucci')
# (None, 'Feednation', None, None)
# (None, 'Jabbercube', None, None)
# (None, 'Twimm', None, None)
# (111, 'Cogilith', 'Kellia', 'Robinson')
# (109, 'Bubblemix', 'Orelle', 'Rean')
# (None, 'Rhynyx', None, None)
# (131, 'Gabtype', 'Briney', 'Robinet')
# (126, 'Feedmix', 'Enos', 'Marciek')
# (None, 'Tambee', None, None)
# (140, 'Linkbuzz', 'Hersh', 'Goodrick')
# (None, 'Voolith', None, None)
# (160, 'Rhybox', 'Margarita', 'Philippault')
# (None, 'Thoughtbeat', None, None)
# (None, 'Voonix', None, None)
# (None, 'Mydeo', None, None)
# (179, 'Voonyx', 'Ajay', 'Wince')
# (None, 'Nlounge', None, None)
# (None, 'Edgeclub', None, None)
# (None, 'Innojam', None, None)
# (None, 'Photolist', None, None)
# (None, 'Brightdog', None, None)
# (183, 'Youtags', 'Traver', 'Beckford')
# (None, 'Fiveclub', None, None)
# (None, 'Chatterpoint', None, None)
# (None, 'Oodoo', None, None)
# (None, 'Skyndu', None, None)
# (None, 'Buzzshare', None, None)
# (117, 'Divape', 'Lorine', 'Jarry')
# (148, 'Myworks', 'Magda', 'Slator')
# (141, 'Livetube', 'Teador', 'MacPike')
# (None, 'Blogpad', None, None)
# (112, 'Dablist', 'Zebulen', 'Dyett')
# (None, 'Browsedrive', None, None)
# (None, 'Fiveclub', None, None)
# (None, 'Kazio', None, None)
# (None, 'Jaxbean', None, None)
# (None, 'Blognation', None, None)
# (None, 'Yadel', None, None)
# (None, 'Skibox', None, None)
# (None, 'Blognation', None, None)
# (139, 'Leenti', 'Leona', 'Murricanes')
# (None, 'Mymm', None, None)
# (147, 'Mynte', 'Darda', 'Iacapucci')
# (167, 'Skilith', 'Ossie', 'Moreno')
# (167, 'Skilith', 'Ossie', 'Moreno')
# (None, 'Kimia', None, None)
# (None, 'JumpXS', None, None)
# (None, 'Miboo', None, None)
# (None, 'Blogtag', None, None)
# (None, 'Jabbersphere', None, None)
# (None, 'Kanoodle', None, None)
# (None, 'Skinte', None, None)
# (114, 'Dazzlesphere', 'Orlan', 'Pynner')
# (None, 'Teklist', None, None)
# (None, 'Eazzy', None, None)
# (None, 'Livepath', None, None)
# (None, 'Buzzbean', None, None)
# (127, 'Fivespan', 'Cyndie', "O'Conor")
# (None, 'Skajo', None, None)
# (102, 'Avamba', 'Deb', 'Petruszka')
# (None, 'Kwilith', None, None)
# (153, 'Photobug', 'Pietra', 'McDill')
# (None, 'Wordtune', None, None)
# (None, 'Vinte', None, None)
# (183, 'Youtags', 'Traver', 'Beckford')
# (None, 'Devshare', None, None)
# (None, 'Muxo', None, None)
# (None, 'Midel', None, None)
# (None, 'Bluejam', None, None)
# (108, 'Browsecat', 'Mikaela', 'Doddridge')
# (None, 'Twimbo', None, None)
# (184, 'Zoomcast', 'Ardyce', 'Stones')
# (184, 'Zoomcast', 'Ardyce', 'Stones')
# (177, 'Twiyo', 'Desdemona', 'McKeever')
# (135, 'Jayo', 'Maressa', 'Pickthall')
# (None, 'Skibox', None, None)
# (None, 'Aimbo', None, None)
# (140, 'Linkbuzz', 'Hersh', 'Goodrick')
# (None, 'Linktype', None, None)
# (None, 'Miboo', None, None)
# (None, 'Yozio', None, None)
# (None, 'Rhynyx', None, None)
# (None, 'Twinder', None, None)
# (None, 'Devshare', None, None)
# (None, 'Digitube', None, None)
# (156, 'Quinu', 'Amitie', 'Wybrew')
# (None, 'Yotz', None, None)
# (137, 'Katz', 'Duncan', 'Hanwright')
# (None, 'Quimba', None, None)
# (118, 'Dynabox', 'Paul', 'Vittori')
# (None, 'Agivu', None, None)
# (None, 'Yata', None, None)
# (None, 'Skibox', None, None)
# (None, 'Bluejam', None, None)
# (None, 'Eimbee', None, None)
# (None, 'Skibox', None, None)
# (None, 'Kanoodle', None, None)
# (None, 'Pixope', None, None)
# (None, 'Jetwire', None, None)
# (None, 'Wordify', None, None)
# (None, 'Divanoodle', None, None)
# (None, 'Blogpad', None, None)
# (None, 'Mydeo', None, None)
# (None, 'Avamm', None, None)
# (None, 'Kamba', None, None)
# (None, 'Browseblab', None, None)
# (130, 'Gabspot', 'Abba', 'Marson')
# (None, 'Cogidoo', None, None)
# (None, 'Realmix', None, None)
# (170, 'Tagfeed', 'Dieter', 'Satchel')
# (171, 'Tagfeed', 'Blakelee', "O'Scanlon")
# (None, 'Quimba', None, None)
# (None, 'Oyondu', None, None)
# (154, 'Photofeed', 'Sharyl', 'Billany')
# (None, 'Kwilith', None, None)
# (None, 'Shufflester', None, None)
# (None, 'Eazzy', None, None)
# (None, 'Aimbo', None, None)
# (108, 'Browsecat', 'Mikaela', 'Doddridge')
# (None, 'Tekfly', None, None)
# (None, 'Topdrive', None, None)
# (None, 'Gevee', None, None)

# %%
clients
# Out:
# [(184, 'Zoomcast', 'Ardyce', 'Stones'),
#  (None, 'Buzzbean', None, None),
#  (None, 'Twitternation', None, None),
#  (175, 'Topiczoom', 'Danyelle', 'Feldman'),
#  (182, 'Youbridge', 'Kylen', 'Daughton'),
#  (None, 'Yakijo', None, None),
#  (None, 'Divavu', None, None),
#  (None, 'Skajo', None, None),
#  (174, 'Topicshots', 'Ajay', 'Hamley'),
#  (None, 'Kwideo', None, None),
#  (None, 'Realbuzz', None, None),
#  (178, 'Vinder', 'Kristien', 'Heaford'),
#  (None, 'Devcast', None, None),
#  (None, 'Jamia', None, None),
#  (154, 'Photofeed', 'Sharyl', 'Billany'),
#  (105, 'Brainbox', 'Jodie', 'Francombe'),
#  (None, 'Abatz', None, None),
#  (158, 'Realcube', 'Paul', 'Egan'),
#  (None, 'Twimm', None, None),
#  (None, 'BlogXS', None, None),
#  (None, 'Yoveo', None, None),
#  (None, 'Midel', None, None),
#  (None, 'Janyx', None, None),
#  (138, 'Kazu', 'Stacee', 'Langford'),
#  (None, 'Oyoba', None, None),
#  (128, 'Flashpoint', 'Dilly', 'Brampton'),
#  (None, 'Kwideo', None, None),
#  (None, 'Topicware', None, None),
#  (None, 'Wikizz', None, None),
#  (None, 'Thoughtworks', None, None),
#  (None, 'Jaxworks', None, None),
#  (None, 'Snaptags', None, None),
#  (None, 'Yombu', None, None),
#  (None, 'Skinder', None, None),
#  (None, 'Shufflebeat', None, None),
#  (None, 'Jamia', None, None),
#  (None, 'Skinte', None, None),
#  (None, 'Brainverse', None, None),
#  (None, 'Eayo', None, None),
#  (None, 'Edgepulse', None, None),
#  (135, 'Jayo', 'Maressa', 'Pickthall'),
#  (None, 'Topiclounge', None, None),
#  (None, 'Fanoodle', None, None),
#  (175, 'Topiczoom', 'Danyelle', 'Feldman'),
#  (182, 'Youbridge', 'Kylen', 'Daughton'),
#  (None, 'Demimbu', None, None),
#  (None, 'Kimia', None, None),
#  (None, 'Zooxo', None, None),
#  (None, 'Flipopia', None, None),
#  (None, 'Wordpedia', None, None),
#  (None, 'Skiptube', None, None),
#  (None, 'Zoonoodle', None, None),
#  (125, 'Feedfish', 'Jerri', 'Husthwaite'),
#  (None, 'Devcast', None, None),
#  (None, 'Fliptune', None, None),
#  (None, 'Yabox', None, None),
#  (None, 'Midel', None, None),
#  (175, 'Topiczoom', 'Danyelle', 'Feldman'),
#  (158, 'Realcube', 'Paul', 'Egan'),
#  (None, 'Tazzy', None, None),
#  (154, 'Photofeed', 'Sharyl', 'Billany'),
#  (None, 'Skiptube', None, None),
#  (None, 'Yodo', None, None),
#  (None, 'Jetwire', None, None),
#  (None, 'Cogidoo', None, None),
#  (135, 'Jayo', 'Maressa', 'Pickthall'),
#  (None, 'Yakitri', None, None),
#  (None, 'Linklinks', None, None),
#  (144, 'Minyx', 'Stefania', 'Drews'),
#  (118, 'Dynabox', 'Paul', 'Vittori'),
#  (163, 'Riffpedia', 'Nickolas', 'Lambert'),
#  (None, 'Rhynyx', None, None),
#  (147, 'Mynte', 'Darda', 'Iacapucci'),
#  (None, 'Edgeblab', None, None),
#  (123, 'Fatz', 'Beitris', 'Jorioz'),
#  (None, 'Viva', None, None),
#  (None, 'Yakijo', None, None),
#  (None, 'Jetpulse', None, None),
#  (None, 'Twinte', None, None),
#  (None, 'Devpoint', None, None),
#  (None, 'Fivechat', None, None),
#  (None, 'Dabtype', None, None),
#  (None, 'Feedfire', None, None),
#  (None, 'Rooxo', None, None),
#  (None, 'Photobean', None, None),
#  (None, 'Thoughtworks', None, None),
#  (None, 'Youfeed', None, None),
#  (None, 'Skipfire', None, None),
#  (None, 'Jabberbean', None, None),
#  (170, 'Tagfeed', 'Dieter', 'Satchel'),
#  (171, 'Tagfeed', 'Blakelee', "O'Scanlon"),
#  (None, 'Zooxo', None, None),
#  (None, 'Shufflester', None, None),
#  (120, 'Eare', 'Bel', 'Caughan'),
#  (139, 'Leenti', 'Leona', 'Murricanes'),
#  (None, 'Divavu', None, None),
#  (176, 'Twitterbridge', 'Harmonia', "O'Hederscoll"),
#  (None, 'DabZ', None, None),
#  (None, 'Trupe', None, None),
#  (None, 'Fanoodle', None, None),
#  (None, 'Meezzy', None, None),
#  (None, 'Vimbo', None, None),
#  (None, 'Tazzy', None, None),
#  (None, 'Chatterpoint', None, None),
#  (None, 'Trilia', None, None),
#  (None, 'Twinder', None, None),
#  (None, 'Rhynyx', None, None),
#  (None, 'Jabbercube', None, None),
#  (153, 'Photobug', 'Pietra', 'McDill'),
#  (None, 'Zooxo', None, None),
#  (None, 'Jaloo', None, None),
#  (None, 'Twitterbeat', None, None),
#  (None, 'Lajo', None, None),
#  (183, 'Youtags', 'Traver', 'Beckford'),
#  (None, 'Fliptune', None, None),
#  (None, 'Oyoba', None, None),
#  (None, 'Realbridge', None, None),
#  (133, 'Jatri', 'Winonah', 'Samson'),
#  (134, 'Jatri', 'Niccolo', 'Bram'),
#  (None, 'Mydo', None, None),
#  (None, 'Tanoodle', None, None),
#  (None, 'Agimba', None, None),
#  (None, 'Demimbu', None, None),
#  (None, 'Mudo', None, None),
#  (119, 'Eadel', 'Pearline', 'Brigham'),
#  (None, 'Dabjam', None, None),
#  (None, 'Mudo', None, None),
#  (None, 'Innojam', None, None),
#  (None, 'Linklinks', None, None),
#  (None, 'Skajo', None, None),
#  (None, 'Jaxnation', None, None),
#  (None, 'Edgetag', None, None),
#  (None, 'Flashspan', None, None),
#  (None, 'BlogXS', None, None),
#  (109, 'Bubblemix', 'Orelle', 'Rean'),
#  (181, 'Yamia', 'Ilario', 'Keedy'),
#  (181, 'Yamia', 'Ilario', 'Keedy'),
#  (None, 'Fanoodle', None, None),
#  (None, 'Twitterworks', None, None),
#  (None, 'Divavu', None, None),
#  (None, 'Tagcat', None, None),
#  (None, 'Feednation', None, None),
#  (None, 'Plajo', None, None),
#  (None, 'Tagcat', None, None),
#  (137, 'Katz', 'Duncan', 'Hanwright'),
#  (None, 'Janyx', None, None),
#  (None, 'Nlounge', None, None),
#  (177, 'Twiyo', 'Desdemona', 'McKeever'),
#  (None, 'Aimbu', None, None),
#  (None, 'Devify', None, None),
#  (119, 'Eadel', 'Pearline', 'Brigham'),
#  (None, 'Jetwire', None, None),
#  (130, 'Gabspot', 'Abba', 'Marson'),
#  (177, 'Twiyo', 'Desdemona', 'McKeever'),
#  (None, 'Geba', None, None),
#  (None, 'Riffwire', None, None),
#  (None, 'Youspan', None, None),
#  (165, 'Skaboo', 'Mord', 'Cook'),
#  (None, 'Browseblab', None, None),
#  (None, 'Skinix', None, None),
#  (115, 'Demivee', 'Adamo', 'Matuszinski'),
#  (None, 'Eidel', None, None),
#  (158, 'Realcube', 'Paul', 'Egan'),
#  (None, 'Brightdog', None, None),
#  (None, 'Skiba', None, None),
#  (None, 'Chatterbridge', None, None),
#  (None, 'Meedoo', None, None),
#  (None, 'Browseblab', None, None),
#  (None, 'Quatz', None, None),
#  (None, 'Browsezoom', None, None),
#  (135, 'Jayo', 'Maressa', 'Pickthall'),
#  (None, 'Jaxnation', None, None),
#  (None, 'Voolith', None, None),
#  (None, 'Chatterbridge', None, None),
#  (115, 'Demivee', 'Adamo', 'Matuszinski'),
#  (None, 'Flashspan', None, None),
#  (None, 'Tagcat', None, None),
#  (None, 'Dabjam', None, None),
#  (173, 'Thoughtstorm', 'Bunni', 'Breen'),
#  (153, 'Photobug', 'Pietra', 'McDill'),
#  (None, 'Vinte', None, None),
#  (None, 'Jamia', None, None),
#  (147, 'Mynte', 'Darda', 'Iacapucci'),
#  (179, 'Voonyx', 'Ajay', 'Wince'),
#  (None, 'Skyba', None, None),
#  (158, 'Realcube', 'Paul', 'Egan'),
#  (None, 'Flipbug', None, None),
#  (None, 'Brightbean', None, None),
#  (None, 'Realfire', None, None),
#  (169, 'Skyvu', 'Rey', 'Salzen'),
#  (173, 'Thoughtstorm', 'Bunni', 'Breen'),
#  (None, 'Blogspan', None, None),
#  (None, 'Yozio', None, None),
#  (None, 'Babblestorm', None, None),
#  (None, 'Talane', None, None),
#  (None, 'Skajo', None, None),
#  (None, 'Fiveclub', None, None),
#  (None, 'Viva', None, None),
#  (None, 'Wordpedia', None, None),
#  (None, 'Izio', None, None),
#  (102, 'Avamba', 'Deb', 'Petruszka'),
#  (None, 'Vipe', None, None),
#  (None, 'Divavu', None, None),
#  (123, 'Fatz', 'Beitris', 'Jorioz'),
#  (None, 'Devify', None, None),
#  (None, 'Gigashots', None, None),
#  (None, 'Edgeblab', None, None),
#  (None, 'Dabjam', None, None),
#  (None, 'Tagopia', None, None),
#  (None, 'Skajo', None, None),
#  (None, 'Camido', None, None),
#  (147, 'Mynte', 'Darda', 'Iacapucci'),
#  (None, 'Talane', None, None),
#  (None, 'Divanoodle', None, None),
#  (139, 'Leenti', 'Leona', 'Murricanes'),
#  (105, 'Brainbox', 'Jodie', 'Francombe'),
#  (None, 'Shuffletag', None, None),
#  (None, 'Voomm', None, None),
#  (None, 'Mydeo', None, None),
#  (None, 'Kayveo', None, None),
#  (161, 'Rhyloo', 'Sasha', 'Clewley'),
#  (None, 'Pixope', None, None),
#  (None, 'Trudeo', None, None),
#  (165, 'Skaboo', 'Mord', 'Cook'),
#  (None, 'Trilith', None, None),
#  (None, 'Quire', None, None),
#  (None, 'Leexo', None, None),
#  (None, 'Fliptune', None, None),
#  (None, 'Yozio', None, None),
#  (None, 'Thoughtbeat', None, None),
#  (174, 'Topicshots', 'Ajay', 'Hamley'),
#  (None, 'Vimbo', None, None),
#  (None, 'Skinix', None, None),
#  (None, 'Quatz', None, None),
#  (123, 'Fatz', 'Beitris', 'Jorioz'),
#  (None, 'Tazzy', None, None),
#  (None, 'Feedspan', None, None),
#  (None, 'Centimia', None, None),
#  (None, 'Dabshots', None, None),
#  (141, 'Livetube', 'Teador', 'MacPike'),
#  (None, 'Mymm', None, None),
#  (141, 'Livetube', 'Teador', 'MacPike'),
#  (160, 'Rhybox', 'Margarita', 'Philippault'),
#  (None, 'Devpulse', None, None),
#  (None, 'Devpulse', None, None),
#  (154, 'Photofeed', 'Sharyl', 'Billany'),
#  (None, 'Voolith', None, None),
#  (131, 'Gabtype', 'Briney', 'Robinet'),
#  (None, 'Trilia', None, None),
#  (None, 'Skinder', None, None),
#  (None, 'Innotype', None, None),
#  (None, 'Voomm', None, None),
#  (None, 'Lajo', None, None),
#  (None, 'Trudeo', None, None),
#  (None, 'Youspan', None, None),
#  (None, 'Edgepulse', None, None),
#  (None, 'Bluejam', None, None),
#  (None, 'Skinder', None, None),
#  (None, 'Divavu', None, None),
#  (147, 'Mynte', 'Darda', 'Iacapucci'),
#  (166, 'Skalith', 'Mandi', 'Syseland'),
#  (None, 'Wikizz', None, None),
#  (None, 'Quimm', None, None),
#  (None, 'Yakitri', None, None),
#  (None, 'Trudoo', None, None),
#  (None, 'Camido', None, None),
#  (None, 'Jaxspan', None, None),
#  (None, 'Zoomdog', None, None),
#  (None, 'Centizu', None, None),
#  (None, 'Cogibox', None, None),
#  (153, 'Photobug', 'Pietra', 'McDill'),
#  (None, 'Eabox', None, None),
#  (None, 'Youspan', None, None),
#  (None, 'Linktype', None, None),
#  (137, 'Katz', 'Duncan', 'Hanwright'),
#  (None, 'Eimbee', None, None),
#  (None, 'Yotz', None, None),
#  (None, 'Fanoodle', None, None),
#  (None, 'Gigashots', None, None),
#  (None, 'Blogpad', None, None),
#  (None, 'Wikivu', None, None),
#  (None, 'Jabbercube', None, None),
#  (151, 'Oozz', 'Marje', 'Weldon'),
#  (None, 'Quimba', None, None),
#  (None, 'Jaxworks', None, None),
#  (None, 'Trupe', None, None),
#  (None, 'Abatz', None, None),
#  (None, 'Topicblab', None, None),
#  (None, 'Dabjam', None, None),
#  (154, 'Photofeed', 'Sharyl', 'Billany'),
#  (158, 'Realcube', 'Paul', 'Egan'),
#  (None, 'Tagchat', None, None),
#  (118, 'Dynabox', 'Paul', 'Vittori'),
#  (None, 'Dabjam', None, None),
#  (None, 'Twimm', None, None),
#  (None, 'Zoonder', None, None),
#  (159, 'Reallinks', 'Brietta', 'Hazel'),
#  (170, 'Tagfeed', 'Dieter', 'Satchel'),
#  (171, 'Tagfeed', 'Blakelee', "O'Scanlon"),
#  (160, 'Rhybox', 'Margarita', 'Philippault'),
#  (None, 'Shufflebeat', None, None),
#  (147, 'Mynte', 'Darda', 'Iacapucci'),
#  (None, 'Flipopia', None, None),
#  (None, 'Skibox', None, None),
#  (None, 'Skippad', None, None),
#  (None, 'Vitz', None, None),
#  (None, 'Dynazzy', None, None),
#  (None, 'Yombu', None, None),
#  (None, 'Tagopia', None, None),
#  (173, 'Thoughtstorm', 'Bunni', 'Breen'),
#  (None, 'Roomm', None, None),
#  (None, 'Mymm', None, None),
#  (None, 'Skimia', None, None),
#  (138, 'Kazu', 'Stacee', 'Langford'),
#  (158, 'Realcube', 'Paul', 'Egan'),
#  (107, 'Browsebug', 'Tobie', 'Arran'),
#  (None, 'Voonte', None, None),
#  (None, 'Eayo', None, None),
#  (156, 'Quinu', 'Amitie', 'Wybrew'),
#  (None, 'Ooba', None, None),
#  (None, 'Yakijo', None, None),
#  (None, 'Tagopia', None, None),
#  (None, 'Wordtune', None, None),
#  (114, 'Dazzlesphere', 'Orlan', 'Pynner'),
#  (None, 'Fivebridge', None, None),
#  (None, 'Digitube', None, None),
#  (None, 'Flipbug', None, None),
#  (None, 'Dynava', None, None),
#  (None, 'Ailane', None, None),
#  (None, 'Trudeo', None, None),
#  (None, 'Kwilith', None, None),
#  (None, 'Viva', None, None),
#  (154, 'Photofeed', 'Sharyl', 'Billany'),
#  (None, 'Pixope', None, None),
#  (None, 'Devpoint', None, None),
#  (None, 'Fivechat', None, None),
#  (None, 'Youopia', None, None),
#  (None, 'Photolist', None, None),
#  (None, 'Devshare', None, None),
#  (None, 'Meevee', None, None),
#  (None, 'Viva', None, None),
#  (None, 'Lazzy', None, None),
#  (None, 'Rooxo', None, None),
#  (None, 'Skippad', None, None),
#  (None, 'Jabbersphere', None, None),
#  (None, 'Twinder', None, None),
#  (None, 'Quaxo', None, None),
#  (143, 'Meetz', 'Alphonse', 'Warboy'),
#  (None, 'Kwilith', None, None),
#  (None, 'Centizu', None, None),
#  (None, 'Zoombox', None, None),
#  (None, 'Zava', None, None),
#  (None, 'Oyoba', None, None),
#  (None, 'Oyoyo', None, None),
#  (None, 'Photolist', None, None),
#  (None, 'Babbleblab', None, None),
#  (None, 'Lazzy', None, None),
#  (None, 'Twitterworks', None, None),
#  (143, 'Meetz', 'Alphonse', 'Warboy'),
#  (None, 'Flashset', None, None),
#  (176, 'Twitterbridge', 'Harmonia', "O'Hederscoll"),
#  (None, 'Divanoodle', None, None),
#  (129, 'Flipstorm', 'Candace', 'Pantling'),
#  (126, 'Feedmix', 'Enos', 'Marciek'),
#  (122, 'Edgewire', 'Merell', 'Meake'),
#  (None, 'Edgetag', None, None),
#  (None, 'Edgeclub', None, None),
#  (None, 'Blogspan', None, None),
#  (None, 'Teklist', None, None),
#  (None, 'Twitternation', None, None),
#  (None, 'Buzzdog', None, None),
#  (157, 'Realblab', 'Lilia', 'Point'),
#  (None, 'Topicblab', None, None),
#  (None, 'Dabfeed', None, None),
#  (149, 'Npath', 'Farris', 'Tulk'),
#  (None, 'Skidoo', None, None),
#  (183, 'Youtags', 'Traver', 'Beckford'),
#  (None, 'Linktype', None, None),
#  (155, 'Pixoboo', 'Davine', 'Trenholme'),
#  (None, 'Gigazoom', None, None),
#  (None, 'Thoughtbeat', None, None),
#  (None, 'Blogtags', None, None),
#  (None, 'Camido', None, None),
#  (None, 'Quimba', None, None),
#  (None, 'Livepath', None, None),
#  (140, 'Linkbuzz', 'Hersh', 'Goodrick'),
#  (None, 'Cogidoo', None, None),
#  (None, 'Twitternation', None, None),
#  (None, 'Buzzbean', None, None),
#  (159, 'Reallinks', 'Brietta', 'Hazel'),
#  (None, 'Jabbercube', None, None),
#  (None, 'Browsezoom', None, None),
#  (None, 'Topiclounge', None, None),
#  (None, 'Yodo', None, None),
#  (None, 'Wordtune', None, None),
#  (None, 'Realbuzz', None, None),
#  (None, 'Yakidoo', None, None),
#  (None, 'Twimm', None, None),
#  (None, 'Tagtune', None, None),
#  (None, 'Yacero', None, None),
#  (None, 'Buzzdog', None, None),
#  (101, 'Aivee', 'Melli', 'Bartolomeotti'),
#  (None, 'Bluejam', None, None),
#  (None, 'Oyonder', None, None),
#  (None, 'Zoovu', None, None),
#  (None, 'Plambee', None, None),
#  (None, 'Gabcube', None, None),
#  (None, 'Eimbee', None, None),
#  (None, 'Oyondu', None, None),
#  (111, 'Cogilith', 'Kellia', 'Robinson'),
#  (None, 'Jetwire', None, None),
#  (None, 'Centimia', None, None),
#  (None, 'Fivechat', None, None),
#  (100, 'Ainyx', 'Timmie', 'Axston'),
#  (None, 'Tazzy', None, None),
#  (None, 'Gabtune', None, None),
#  (None, 'Thoughtmix', None, None),
#  (None, 'Jaxnation', None, None),
#  (None, 'Viva', None, None),
#  (None, 'Kwimbee', None, None),
#  (None, 'Rhynoodle', None, None),
#  (None, 'Skinte', None, None),
#  (None, 'Wordpedia', None, None),
#  (108, 'Browsecat', 'Mikaela', 'Doddridge'),
#  (None, 'Linktype', None, None),
#  (123, 'Fatz', 'Beitris', 'Jorioz'),
#  (None, 'Thoughtblab', None, None),
#  (None, 'Aimbo', None, None),
#  (137, 'Katz', 'Duncan', 'Hanwright'),
#  (None, 'Eidel', None, None),
#  (155, 'Pixoboo', 'Davine', 'Trenholme'),
#  (None, 'Jabberstorm', None, None),
#  (None, 'Meeveo', None, None),
#  (None, 'Youfeed', None, None),
#  (None, 'Twimbo', None, None),
#  (117, 'Divape', 'Lorine', 'Jarry'),
#  (None, 'Skinte', None, None),
#  (None, 'Shufflebeat', None, None),
#  (None, 'Devpoint', None, None),
#  (None, 'Realfire', None, None),
#  (None, 'Edgepulse', None, None),
#  (None, 'Mybuzz', None, None),
#  (None, 'Gigazoom', None, None),
#  (129, 'Flipstorm', 'Candace', 'Pantling'),
#  (None, 'Quaxo', None, None),
#  (177, 'Twiyo', 'Desdemona', 'McKeever'),
#  (None, 'Wikizz', None, None),
#  (None, 'Brainsphere', None, None),
#  (135, 'Jayo', 'Maressa', 'Pickthall'),
#  (None, 'Tagchat', None, None),
#  (None, 'Quamba', None, None),
#  (None, 'Zoonder', None, None),
#  (None, 'Tanoodle', None, None),
#  (None, 'Blognation', None, None),
#  (None, 'Nlounge', None, None),
#  (None, 'Eayo', None, None),
#  (None, 'Tagopia', None, None),
#  (158, 'Realcube', 'Paul', 'Egan'),
#  (None, 'Wordware', None, None),
#  (None, 'Vinte', None, None),
#  (None, 'Lazzy', None, None),
#  (166, 'Skalith', 'Mandi', 'Syseland'),
#  (148, 'Myworks', 'Magda', 'Slator'),
#  (None, 'Kimia', None, None),
#  (None, 'Centimia', None, None),
#  (140, 'Linkbuzz', 'Hersh', 'Goodrick'),
#  (None, 'Skipfire', None, None),
#  (None, 'Feedfire', None, None),
#  (106, 'Brainlounge', 'Dyana', 'Mingame'),
#  (None, 'Kwimbee', None, None),
#  (None, 'Voonder', None, None),
#  (None, 'Camimbo', None, None),
#  (None, 'Dabshots', None, None),
#  (None, 'Jabberstorm', None, None),
#  (None, 'Jamia', None, None),
#  (None, 'Trupe', None, None),
#  (None, 'Bubbletube', None, None),
#  (None, 'Quatz', None, None),
#  (None, 'Yacero', None, None),
#  (178, 'Vinder', 'Kristien', 'Heaford'),
#  (None, 'Fadeo', None, None),
#  (None, 'Twitterlist', None, None),
#  (None, 'JumpXS', None, None),
#  (None, 'Camido', None, None),
#  (None, 'Plambee', None, None),
#  (None, 'Thoughtmix', None, None),
#  (None, 'Bluejam', None, None),
#  (141, 'Livetube', 'Teador', 'MacPike'),
#  (None, 'Oyonder', None, None),
#  (139, 'Leenti', 'Leona', 'Murricanes'),
#  (None, 'Oyoloo', None, None),
#  (None, 'Centimia', None, None),
#  (None, 'Babblestorm', None, None),
#  (None, 'Ozu', None, None),
#  (149, 'Npath', 'Farris', 'Tulk'),
#  (None, 'Oloo', None, None),
#  (None, 'Twitterwire', None, None),
#  (None, 'Oyoba', None, None),
#  (138, 'Kazu', 'Stacee', 'Langford'),
#  (None, 'Jaxworks', None, None),
#  (None, 'Realbuzz', None, None),
#  (None, 'Meeveo', None, None),
#  (164, 'Roombo', 'Rorie', 'Frissell'),
#  (None, 'Miboo', None, None),
#  (None, 'Skiba', None, None),
#  (None, 'Devpulse', None, None),
#  (None, 'Shufflester', None, None),
#  (None, 'Fliptune', None, None),
#  (None, 'Bluezoom', None, None),
#  (None, 'Thoughtblab', None, None),
#  (None, 'Tagchat', None, None),
#  (None, 'Ntag', None, None),
#  (None, 'Oyoloo', None, None),
#  (182, 'Youbridge', 'Kylen', 'Daughton'),
#  (None, 'Quaxo', None, None),
#  (131, 'Gabtype', 'Briney', 'Robinet'),
#  (None, 'Skibox', None, None),
#  (None, 'Twitternation', None, None),
#  (None, 'Thoughtbeat', None, None),
#  (182, 'Youbridge', 'Kylen', 'Daughton'),
#  (157, 'Realblab', 'Lilia', 'Point'),
#  (None, 'Jamia', None, None),
#  (None, 'Buzzbean', None, None),
#  (103, 'Avaveo', 'Dick', 'Borgnol'),
#  (None, 'Browseblab', None, None),
#  (160, 'Rhybox', 'Margarita', 'Philippault'),
#  (None, 'Yabox', None, None),
#  (155, 'Pixoboo', 'Davine', 'Trenholme'),
#  (None, 'Talane', None, None),
#  (None, 'Eimbee', None, None),
#  (None, 'Leexo', None, None),
#  (183, 'Youtags', 'Traver', 'Beckford'),
#  (None, 'Ntags', None, None),
#  (149, 'Npath', 'Farris', 'Tulk'),
#  (None, 'Bluejam', None, None),
#  (None, 'Eimbee', None, None),
#  (170, 'Tagfeed', 'Dieter', 'Satchel'),
#  (171, 'Tagfeed', 'Blakelee', "O'Scanlon"),
#  (None, 'Twitterbeat', None, None),
#  (None, 'Gevee', None, None),
#  (141, 'Livetube', 'Teador', 'MacPike'),
#  (None, 'Centimia', None, None),
#  (None, 'Jazzy', None, None),
#  (None, 'Leexo', None, None),
#  (None, 'Bubbletube', None, None),
#  (None, 'Buzzbean', None, None),
#  (None, 'Mydo', None, None),
#  (None, 'Miboo', None, None),
#  (None, 'Quire', None, None),
#  (None, 'Browseblab', None, None),
#  (164, 'Roombo', 'Rorie', 'Frissell'),
#  (None, 'Skinder', None, None),
#  (None, 'Jabberbean', None, None),
#  (None, 'Janyx', None, None),
#  (None, 'Blognation', None, None),
#  (None, 'Trunyx', None, None),
#  (None, 'Ntag', None, None),
#  (None, 'Yodoo', None, None),
#  (None, 'Devshare', None, None),
#  (None, 'Blogpad', None, None),
#  (None, 'Bubblebox', None, None),
#  (None, 'Devshare', None, None),
#  (None, 'Skyble', None, None),
#  (112, 'Dablist', 'Zebulen', 'Dyett'),
#  (151, 'Oozz', 'Marje', 'Weldon'),
#  (None, 'Zoovu', None, None),
#  (None, 'Devshare', None, None),
#  (None, 'Quimm', None, None),
#  (None, 'Bluezoom', None, None),
#  (None, 'Yodel', None, None),
#  (None, 'Skyndu', None, None),
#  (None, 'Fivebridge', None, None),
#  (145, 'Mita', 'Kassandra', 'Marks'),
#  (None, 'Digitube', None, None),
#  (None, 'Meezzy', None, None),
#  (None, 'Gigabox', None, None),
#  (None, 'Devpoint', None, None),
#  (None, 'Trudoo', None, None),
#  (None, 'Ooba', None, None),
#  (None, 'Tavu', None, None),
#  (None, 'Shuffledrive', None, None),
#  (None, 'Oyoloo', None, None),
#  (None, 'Flashdog', None, None),
#  (None, 'Aimbo', None, None),
#  (None, 'Yodo', None, None),
#  (162, 'Riffpath', 'Rayna', 'Lepere'),
#  (None, 'Babbleblab', None, None),
#  (103, 'Avaveo', 'Dick', 'Borgnol'),
#  (164, 'Roombo', 'Rorie', 'Frissell'),
#  (152, 'Oyope', 'Jenny', 'Curle'),
#  (None, 'Gigashots', None, None),
#  (None, 'Rhynyx', None, None),
#  (122, 'Edgewire', 'Merell', 'Meake'),
#  (None, 'Quamba', None, None),
#  (None, 'Bubblebox', None, None),
#  (None, 'Vitz', None, None),
#  (None, 'Babblestorm', None, None),
#  (None, 'Aimbu', None, None),
#  (None, 'Brightbean', None, None),
#  (None, 'Mydo', None, None),
#  (None, 'Wordpedia', None, None),
#  (None, 'Vipe', None, None),
#  (None, 'Realpoint', None, None),
#  (None, 'Fliptune', None, None),
#  (182, 'Youbridge', 'Kylen', 'Daughton'),
#  (None, 'Linktype', None, None),
#  (None, 'Tagcat', None, None),
#  (None, 'Thoughtblab', None, None),
#  (None, 'Topicware', None, None),
#  (None, 'Babbleset', None, None),
#  (None, 'Voonte', None, None),
#  (None, 'Quire', None, None),
#  (None, 'Latz', None, None),
#  (172, 'Tazz', 'Dom', 'Cremins'),
#  (None, 'Blognation', None, None),
#  (None, 'Muxo', None, None),
#  (None, 'Izio', None, None),
#  (None, 'Edgepulse', None, None),
#  (114, 'Dazzlesphere', 'Orlan', 'Pynner'),
#  (None, 'Vidoo', None, None),
#  (121, 'Edgeify', 'Katina', 'Orrocks'),
#  (None, 'Brightdog', None, None),
#  (None, 'Zoomzone', None, None),
#  (183, 'Youtags', 'Traver', 'Beckford'),
#  (None, 'Gigabox', None, None),
#  (None, 'Topicware', None, None),
#  (None, 'Wordify', None, None),
#  (None, 'Demimbu', None, None),
#  (109, 'Bubblemix', 'Orelle', 'Rean'),
#  (124, 'Feedbug', 'Andee', 'Cramp'),
#  (None, 'Janyx', None, None),
#  (None, 'Dynava', None, None),
#  (175, 'Topiczoom', 'Danyelle', 'Feldman'),
#  (153, 'Photobug', 'Pietra', 'McDill'),
#  (None, 'Realpoint', None, None),
#  (None, 'Flipopia', None, None),
#  (None, 'Yakitri', None, None),
#  (None, 'Gabtune', None, None),
#  (None, 'Tagpad', None, None),
#  (None, 'Jamia', None, None),
#  (None, 'Topdrive', None, None),
#  (None, 'Flipopia', None, None),
#  (132, 'InnoZ', 'Nicoline', 'Milmore'),
#  (None, 'Feednation', None, None),
#  (None, 'Eimbee', None, None),
#  (None, 'Devcast', None, None),
#  (None, 'Trudoo', None, None),
#  (None, 'Meezzy', None, None),
#  (None, 'Kimia', None, None),
#  (None, 'Ntags', None, None),
#  (181, 'Yamia', 'Ilario', 'Keedy'),
#  (None, 'Trupe', None, None),
#  (None, 'Aimbu', None, None),
#  (None, 'Pixope', None, None),
#  (None, 'Aibox', None, None),
#  (None, 'Trunyx', None, None),
#  (167, 'Skilith', 'Ossie', 'Moreno'),
#  (141, 'Livetube', 'Teador', 'MacPike'),
#  (None, 'Ailane', None, None),
#  (None, 'Latz', None, None),
#  (None, 'Gigabox', None, None),
#  (105, 'Brainbox', 'Jodie', 'Francombe'),
#  (None, 'Oyoba', None, None),
#  (None, 'Talane', None, None),
#  (None, 'Fanoodle', None, None),
#  (None, 'Voonder', None, None),
#  (None, 'Yodoo', None, None),
#  (153, 'Photobug', 'Pietra', 'McDill'),
#  (None, 'Buzzdog', None, None),
#  (111, 'Cogilith', 'Kellia', 'Robinson'),
#  (None, 'Photobean', None, None),
#  (None, 'Camido', None, None),
#  (None, 'Quire', None, None),
#  (None, 'Jabbercube', None, None),
#  (121, 'Edgeify', 'Katina', 'Orrocks'),
#  (None, 'Voonder', None, None),
#  (None, 'Fliptune', None, None),
#  (None, 'Jaxnation', None, None),
#  (161, 'Rhyloo', 'Sasha', 'Clewley'),
#  (142, 'Meejo', 'Abran', 'Antoniat'),
#  (174, 'Topicshots', 'Ajay', 'Hamley'),
#  (None, 'Muxo', None, None),
#  (None, 'Jaxspan', None, None),
#  (None, 'Jaxbean', None, None),
#  (None, 'Bubbletube', None, None),
#  (None, 'Twitternation', None, None),
#  (None, 'Brainverse', None, None),
#  (None, 'Feednation', None, None),
#  (None, 'Realmix', None, None),
#  (None, 'Meedoo', None, None),
#  (None, 'Livefish', None, None),
#  (None, 'Skyndu', None, None),
#  (None, 'Skinder', None, None),
#  (None, 'Voolith', None, None),
#  (None, 'Flipopia', None, None),
#  (None, 'Riffwire', None, None),
#  (None, 'Oyoba', None, None),
#  (None, 'Abatz', None, None),
#  (181, 'Yamia', 'Ilario', 'Keedy'),
#  (None, 'Meevee', None, None),
#  (None, 'Topicware', None, None),
#  (None, 'Lajo', None, None),
#  (None, 'Digitube', None, None),
#  (None, 'Blogtag', None, None),
#  (108, 'Browsecat', 'Mikaela', 'Doddridge'),
#  (None, 'Thoughtbeat', None, None),
#  (None, 'Twimbo', None, None),
#  (None, 'Ooba', None, None),
#  (None, 'Jabbersphere', None, None),
#  (None, 'Yakitri', None, None),
#  (None, 'Quatz', None, None),
#  (None, 'Browseblab', None, None),
#  (None, 'Browseblab', None, None),
#  (None, 'Yakidoo', None, None),
#  (None, 'Trunyx', None, None),
#  (133, 'Jatri', 'Winonah', 'Samson'),
#  (134, 'Jatri', 'Niccolo', 'Bram'),
#  (None, 'Skyndu', None, None),
#  (None, 'Meeveo', None, None),
#  (None, 'Skimia', None, None),
#  (132, 'InnoZ', 'Nicoline', 'Milmore'),
#  (161, 'Rhyloo', 'Sasha', 'Clewley'),
#  (151, 'Oozz', 'Marje', 'Weldon'),
#  (None, 'Thoughtbeat', None, None),
#  (None, 'Quimba', None, None),
#  (None, 'Browseblab', None, None),
#  (137, 'Katz', 'Duncan', 'Hanwright'),
#  (None, 'Rhycero', None, None),
#  (None, 'Devcast', None, None),
#  (None, 'Ailane', None, None),
#  (None, 'Shufflebeat', None, None),
#  (None, 'Topicblab', None, None),
#  (None, 'Abata', None, None),
#  (143, 'Meetz', 'Alphonse', 'Warboy'),
#  (176, 'Twitterbridge', 'Harmonia', "O'Hederscoll"),
#  (None, 'Meevee', None, None),
#  (None, 'Photojam', None, None),
#  (None, 'Thoughtblab', None, None),
#  (None, 'Viva', None, None),
#  (None, 'Rhynyx', None, None),
#  (137, 'Katz', 'Duncan', 'Hanwright'),
#  (144, 'Minyx', 'Stefania', 'Drews'),
#  (None, 'Devpoint', None, None),
#  (None, 'Kwilith', None, None),
#  (None, 'Gevee', None, None),
#  (None, 'Skinder', None, None),
#  (None, 'Browseblab', None, None),
#  (None, 'Photolist', None, None),
#  (123, 'Fatz', 'Beitris', 'Jorioz'),
#  (None, 'Roomm', None, None),
#  (None, 'Kimia', None, None),
#  (None, 'Oodoo', None, None),
#  (None, 'Quire', None, None),
#  (None, 'Cogidoo', None, None),
#  (152, 'Oyope', 'Jenny', 'Curle'),
#  (None, 'Cogidoo', None, None),
#  (None, 'Buzzshare', None, None),
#  (None, 'Wikizz', None, None),
#  (None, 'Yambee', None, None),
#  (None, 'Wikido', None, None),
#  (None, 'Voonix', None, None),
#  (168, 'Skipstorm', 'Dela', 'Dashkovich'),
#  (None, 'Camido', None, None),
#  (None, 'Eamia', None, None),
#  (156, 'Quinu', 'Amitie', 'Wybrew'),
#  (None, 'Kayveo', None, None),
#  (128, 'Flashpoint', 'Dilly', 'Brampton'),
#  (None, 'Youspan', None, None),
#  (None, 'Photospace', None, None),
#  (None, 'Devpulse', None, None),
#  (104, 'Babbleopia', 'Bendick', 'Sawkin'),
#  (166, 'Skalith', 'Mandi', 'Syseland'),
#  (None, 'Yakijo', None, None),
#  (None, 'Divavu', None, None),
#  (141, 'Livetube', 'Teador', 'MacPike'),
#  (None, 'Tagopia', None, None),
#  (None, 'Abata', None, None),
#  (None, 'Rhynyx', None, None),
#  (None, 'Eazzy', None, None),
#  (None, 'Kimia', None, None),
#  (None, 'Camido', None, None),
#  (None, 'Zoonoodle', None, None),
#  (158, 'Realcube', 'Paul', 'Egan'),
#  (None, 'Voolia', None, None),
#  (None, 'Eabox', None, None),
#  (None, 'Quatz', None, None),
#  (None, 'Quimm', None, None),
#  (None, 'Browseblab', None, None),
#  (None, 'Devshare', None, None),
#  (None, 'Photospace', None, None),
#  (None, 'Kwilith', None, None),
#  (118, 'Dynabox', 'Paul', 'Vittori'),
#  (178, 'Vinder', 'Kristien', 'Heaford'),
#  (None, 'Gigazoom', None, None),
#  (None, 'Twitterlist', None, None),
#  (None, 'Babbleblab', None, None),
#  (None, 'Blognation', None, None),
#  (None, 'Realbuzz', None, None),
#  (None, 'Yabox', None, None),
#  (None, 'Realbridge', None, None),
#  (None, 'Buzzbean', None, None),
#  (None, 'Bubbletube', None, None),
#  (None, 'Cogibox', None, None),
#  (152, 'Oyope', 'Jenny', 'Curle'),
#  (None, 'Twitterlist', None, None),
#  (None, 'Photojam', None, None),
#  (None, 'Kayveo', None, None),
#  (None, 'Fivechat', None, None),
#  (None, 'JumpXS', None, None),
#  (None, 'Bubblebox', None, None),
#  (None, 'Blogpad', None, None),
#  (None, 'Devpoint', None, None),
#  (118, 'Dynabox', 'Paul', 'Vittori'),
#  (None, 'Quamba', None, None),
#  (None, 'Voonder', None, None),
#  (None, 'Blogtag', None, None),
#  (None, 'Trupe', None, None),
#  (141, 'Livetube', 'Teador', 'MacPike'),
#  (158, 'Realcube', 'Paul', 'Egan'),
#  (None, 'Babbleblab', None, None),
#  (174, 'Topicshots', 'Ajay', 'Hamley'),
#  (147, 'Mynte', 'Darda', 'Iacapucci'),
#  (None, 'Oyoba', None, None),
#  (101, 'Aivee', 'Melli', 'Bartolomeotti'),
#  (None, 'Innotype', None, None),
#  (None, 'Einti', None, None),
#  (None, 'Kayveo', None, None),
#  (None, 'Gabvine', None, None),
#  (None, 'Linklinks', None, None),
#  (None, 'Gevee', None, None),
#  (None, 'Ooba', None, None),
#  (None, 'Rhynoodle', None, None),
#  (None, 'DabZ', None, None),
#  (None, 'Tekfly', None, None),
#  (None, 'Realfire', None, None),
#  (None, 'Gigabox', None, None),
#  (None, 'Oyonder', None, None),
#  (179, 'Voonyx', 'Ajay', 'Wince'),
#  (178, 'Vinder', 'Kristien', 'Heaford'),
#  (None, 'Plambee', None, None),
#  (None, 'Flashdog', None, None),
#  (None, 'Thoughtblab', None, None),
#  (135, 'Jayo', 'Maressa', 'Pickthall'),
#  (None, 'Jabberstorm', None, None),
#  (100, 'Ainyx', 'Timmie', 'Axston'),
#  (None, 'Twinder', None, None),
#  (None, 'Flipbug', None, None),
#  (None, 'Yakidoo', None, None),
#  (None, 'Vidoo', None, None),
#  (None, 'Blogtags', None, None),
#  (None, 'Quaxo', None, None),
#  (None, 'Gevee', None, None),
#  (None, 'Babbleset', None, None),
#  (None, 'Jaxbean', None, None),
#  (None, 'Yacero', None, None),
#  (None, 'Camido', None, None),
#  (None, 'Vimbo', None, None),
#  (None, 'Wikizz', None, None),
#  (None, 'Edgepulse', None, None),
#  (None, 'Babblestorm', None, None),
#  (None, 'Yakidoo', None, None),
#  (None, 'Buzzdog', None, None),
#  (None, 'Meevee', None, None),
#  (None, 'Livepath', None, None),
#  (None, 'Eidel', None, None),
#  (None, 'Flipbug', None, None),
#  (176, 'Twitterbridge', 'Harmonia', "O'Hederscoll"),
#  (154, 'Photofeed', 'Sharyl', 'Billany'),
#  (None, 'Tambee', None, None),
#  (None, 'Tagchat', None, None),
#  (None, 'Livepath', None, None),
#  (None, 'Wikizz', None, None),
#  (None, 'Twitterworks', None, None),
#  (None, 'Topicstorm', None, None),
#  (160, 'Rhybox', 'Margarita', 'Philippault'),
#  (None, 'Skinte', None, None),
#  (None, 'Kwimbee', None, None),
#  (None, 'Jabbersphere', None, None),
#  (None, 'Leexo', None, None),
#  (None, 'Babbleblab', None, None),
#  (None, 'Kaymbo', None, None),
#  (None, 'Wikido', None, None),
#  (None, 'Eabox', None, None),
#  (147, 'Mynte', 'Darda', 'Iacapucci'),
#  (None, 'Feednation', None, None),
#  (None, 'Jabbercube', None, None),
#  (None, 'Twimm', None, None),
#  (111, 'Cogilith', 'Kellia', 'Robinson'),
#  (109, 'Bubblemix', 'Orelle', 'Rean'),
#  (None, 'Rhynyx', None, None),
#  (131, 'Gabtype', 'Briney', 'Robinet'),
#  (126, 'Feedmix', 'Enos', 'Marciek'),
#  (None, 'Tambee', None, None),
#  (140, 'Linkbuzz', 'Hersh', 'Goodrick'),
#  (None, 'Voolith', None, None),
#  (160, 'Rhybox', 'Margarita', 'Philippault'),
#  (None, 'Thoughtbeat', None, None),
#  (None, 'Voonix', None, None),
#  (None, 'Mydeo', None, None),
#  (179, 'Voonyx', 'Ajay', 'Wince'),
#  (None, 'Nlounge', None, None),
#  (None, 'Edgeclub', None, None),
#  (None, 'Innojam', None, None),
#  (None, 'Photolist', None, None),
#  (None, 'Brightdog', None, None),
#  (183, 'Youtags', 'Traver', 'Beckford'),
#  (None, 'Fiveclub', None, None),
#  (None, 'Chatterpoint', None, None),
#  (None, 'Oodoo', None, None),
#  (None, 'Skyndu', None, None),
#  (None, 'Buzzshare', None, None),
#  (117, 'Divape', 'Lorine', 'Jarry'),
#  (148, 'Myworks', 'Magda', 'Slator'),
#  (141, 'Livetube', 'Teador', 'MacPike'),
#  (None, 'Blogpad', None, None),
#  (112, 'Dablist', 'Zebulen', 'Dyett'),
#  (None, 'Browsedrive', None, None),
#  (None, 'Fiveclub', None, None),
#  (None, 'Kazio', None, None),
#  (None, 'Jaxbean', None, None),
#  (None, 'Blognation', None, None),
#  (None, 'Yadel', None, None),
#  (None, 'Skibox', None, None),
#  (None, 'Blognation', None, None),
#  (139, 'Leenti', 'Leona', 'Murricanes'),
#  (None, 'Mymm', None, None),
#  (147, 'Mynte', 'Darda', 'Iacapucci'),
#  (167, 'Skilith', 'Ossie', 'Moreno'),
#  (167, 'Skilith', 'Ossie', 'Moreno'),
#  (None, 'Kimia', None, None),
#  (None, 'JumpXS', None, None),
#  (None, 'Miboo', None, None),
#  (None, 'Blogtag', None, None),
#  (None, 'Jabbersphere', None, None),
#  (None, 'Kanoodle', None, None),
#  (None, 'Skinte', None, None),
#  (114, 'Dazzlesphere', 'Orlan', 'Pynner'),
#  (None, 'Teklist', None, None),
#  (None, 'Eazzy', None, None),
#  (None, 'Livepath', None, None),
#  (None, 'Buzzbean', None, None),
#  (127, 'Fivespan', 'Cyndie', "O'Conor"),
#  (None, 'Skajo', None, None),
#  (102, 'Avamba', 'Deb', 'Petruszka'),
#  (None, 'Kwilith', None, None),
#  (153, 'Photobug', 'Pietra', 'McDill'),
#  (None, 'Wordtune', None, None),
#  (None, 'Vinte', None, None),
#  (183, 'Youtags', 'Traver', 'Beckford'),
#  (None, 'Devshare', None, None),
#  (None, 'Muxo', None, None),
#  (None, 'Midel', None, None),
#  (None, 'Bluejam', None, None),
#  (108, 'Browsecat', 'Mikaela', 'Doddridge'),
#  (None, 'Twimbo', None, None),
#  (184, 'Zoomcast', 'Ardyce', 'Stones'),
#  (184, 'Zoomcast', 'Ardyce', 'Stones'),
#  (177, 'Twiyo', 'Desdemona', 'McKeever'),
#  (135, 'Jayo', 'Maressa', 'Pickthall'),
#  (None, 'Skibox', None, None),
#  (None, 'Aimbo', None, None),
#  (140, 'Linkbuzz', 'Hersh', 'Goodrick'),
#  (None, 'Linktype', None, None),
#  (None, 'Miboo', None, None),
#  (None, 'Yozio', None, None),
#  (None, 'Rhynyx', None, None),
#  (None, 'Twinder', None, None),
#  (None, 'Devshare', None, None),
#  (None, 'Digitube', None, None),
#  (156, 'Quinu', 'Amitie', 'Wybrew'),
#  (None, 'Yotz', None, None),
#  (137, 'Katz', 'Duncan', 'Hanwright'),
#  (None, 'Quimba', None, None),
#  (118, 'Dynabox', 'Paul', 'Vittori'),
#  (None, 'Agivu', None, None),
#  (None, 'Yata', None, None),
#  (None, 'Skibox', None, None),
#  (None, 'Bluejam', None, None),
#  (None, 'Eimbee', None, None),
#  (None, 'Skibox', None, None),
#  (None, 'Kanoodle', None, None),
#  (None, 'Pixope', None, None),
#  (None, 'Jetwire', None, None),
#  (None, 'Wordify', None, None),
#  (None, 'Divanoodle', None, None),
#  (None, 'Blogpad', None, None),
#  (None, 'Mydeo', None, None),
#  (None, 'Avamm', None, None),
#  (None, 'Kamba', None, None),
#  (None, 'Browseblab', None, None),
#  (130, 'Gabspot', 'Abba', 'Marson'),
#  (None, 'Cogidoo', None, None),
#  (None, 'Realmix', None, None),
#  (170, 'Tagfeed', 'Dieter', 'Satchel'),
#  (171, 'Tagfeed', 'Blakelee', "O'Scanlon"),
#  (None, 'Quimba', None, None),
#  (None, 'Oyondu', None, None),
#  (154, 'Photofeed', 'Sharyl', 'Billany'),
#  (None, 'Kwilith', None, None),
#  (None, 'Shufflester', None, None),
#  ...]

# %%
df = pd.DataFrame(data=clients, columns=
                  [
                      'company_id',
                      'company_name',
                      'contact_first_name',
                      'contact_last_name'
                  ])

df.head()
# Out:
#   company_id   company_name contact_first_name contact_last_name
# 0        184       Zoomcast             Ardyce            Stones
# 1       None       Buzzbean               None              None
# 2       None  Twitternation               None              None
# 3        175      Topiczoom           Danyelle           Feldman
# 4        182      Youbridge              Kylen          Daughton

# %%
# Check rows

df_alpha = df.sort_values(by=['contact_first_name'])
df_alpha.head(10)
# Out:
#      company_id company_name contact_first_name contact_last_name
# 2767        130      Gabspot               Abba            Marson
# 1929        130      Gabspot               Abba            Marson
# 152         130      Gabspot               Abba            Marson
# 990         130      Gabspot               Abba            Marson
# 2456        142        Meejo              Abran          Antoniat
# 679         142        Meejo              Abran          Antoniat
# 174         115      Demivee              Adamo       Matuszinski
# 1951        115      Demivee              Adamo       Matuszinski
# 160         115      Demivee              Adamo       Matuszinski
# 1937        115      Demivee              Adamo       Matuszinski
